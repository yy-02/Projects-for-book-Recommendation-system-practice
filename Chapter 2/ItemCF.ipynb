# %% [markdown]
# # 数据读取

# %%
import pandas as pd
import random
import math
from collections import defaultdict

# 读取用户数据集，指定列名
users = pd.read_csv('users.dat', sep='::', engine='python', header=None,
                    names=['UserID', 'Gender', 'Age', 'Occupation', 'Zip-code'])
print("Users 数据集预览：")
print(users.head())

# 读取电影数据集，指定列名
movies = pd.read_csv('movies.dat', sep='::', engine='python', header=None, encoding='latin1',
                     names=['MovieID', 'Title', 'Genres'])
    
# 将 Genres 列中的字符串按 "|" 分割，转换成列表
movies['Genres'] = movies['Genres'].apply(lambda x: x.split('|'))

print("\nMovies 数据集预览：")
print(movies.head())



# 读取 ratings 数据集
ratings = pd.read_csv('ratings.dat', sep='::', engine='python', header=None,
                        names=['UserID', 'MovieID', 'Rating', 'Timestamp'])
print("Ratings 数据集预览：")
print(ratings.head())

# 对于隐反馈数据，只需要记录 (UserID, MovieID) 对，忽略 Rating 和 Timestamp
data = list(zip(ratings['UserID'], ratings['MovieID']))
# Out:
# Users 数据集预览：
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455
#
# Movies 数据集预览：
#    MovieID                               Title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                              Genres
# 0   [Animation, Children's, Comedy]
# 1  [Adventure, Children's, Fantasy]
# 2                 [Comedy, Romance]
# 3                   [Comedy, Drama]
# 4                          [Comedy]
# Ratings 数据集预览：
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %% [markdown]
# # 数据集划分

# %%
import random

def SplitData(data, M, k, seed):
    """
    将数据集 data 均匀随机划分为 M 份，
    k 为当前划分的编号（0 <= k < M），
    如果某条数据被随机选中为 k，则划分到测试集，
    否则划分到训练集。

    参数:
    - data: 用户行为数据，格式为 [(user, item), ...]
    - M: 划分份数，例如 8
    - k: 本次实验选用的测试集编号，0 <= k < M
    - seed: 随机种子，用于保证实验可重复

    返回:
    - train: 训练集列表
    - test: 测试集列表
    """
    test = []
    train = []
    random.seed(seed)
    for user, item in data:
        # 随机生成 0 到 M-1 之间的一个整数
        if random.randint(0, M - 1) == k:
            test.append([user, item])
        else:
            train.append([user, item])
    return train, test


# 这里选择 M=8，k=0 作为一次实验（可循环不同 k 得到多个结果）
M = 8
k = 0
seed = 42
train_data, test_data = SplitData(data, M, k, seed)

print(f"\n训练集大小: {len(train_data)}, 测试集大小: {len(test_data)}")
# Out:
# 训练集大小: 874948, 测试集大小: 125261

# %% [markdown]
# # 用户-物品集 & 用户相似度

# %% [markdown]
# ## 用户物品集

# %%
# ---------------------------
# 构建用户-物品字典（训练集）
# ---------------------------
def build_user_item_dict(train_data):
    """
    根据训练集，生成 {user: set(items)} 结构
    """
    user_item = defaultdict(set)
    for user, item in train_data:
        user_item[user].add(item)
    return user_item

user_item = build_user_item_dict(train_data)

# %% [markdown]
# ## 物品相似度

# %% [markdown]
# ### 普通版本（可选IUF）

# %%
# ---------------------------
# 计算item相似度
# ---------------------------
def calc_item_similarity(user_item):
    """
    计算物品之间的相似度
    参数:
      user_item: dict, 格式为 {user: set(items)} 表示每个用户交互过的物品集合
    返回:
      item_similarity: dict, 格式为 {i: {j: similarity}}，表示物品 i 与物品 j 的相似度
    """
    # 构建物品-用户倒排表
    item_users = defaultdict(set)
    for user, items in user_item.items():
        for i in items:
            item_users[i].add(user)
    
    # 共现矩阵，用于统计同时出现在同一用户行为中的物品对次数
    co_occurrence = defaultdict(lambda: defaultdict(int))
    # 统计每个物品被交互的次数（即用户数）
    item_count = {i: len(users) for i, users in item_users.items()}
    
    # 遍历每个用户的交互物品，更新共现矩阵
    for user, items in user_item.items():
        items = list(items)
        for i in range(len(items)):
            for j in range(i + 1, len(items)):
                item_i = items[i]
                item_j = items[j]
                co_occurrence[item_i][item_j] += 1
                co_occurrence[item_j][item_i] += 1  # 对称关系

                #对于ItemCF-IUF,只需要 += 1 / math.log(1+len(items))

    # 根据共现矩阵计算余弦相似度
    item_similarity = defaultdict(dict)
    for i, related_items in co_occurrence.items():
        for j, co_count in related_items.items():
            # 注意：如果某个物品没有交互记录，则 item_count[i] 为 0，通常不会出现这种情况
            sim = co_count / math.sqrt(item_count[i] * item_count[j])
            item_similarity[i][j] = sim

    return item_similarity

item_similarity = calc_item_similarity(user_item)

# %% [markdown]
# ### 归一化版本

# %%
# ---------------------------
# 带归一化的
# ---------------------------
def calc_item_similarity_norm(user_item):
    """
    计算物品之间的相似度
    参数:
      user_item: dict, 格式为 {user: set(items)} 表示每个用户交互过的物品集合
    返回:
      item_similarity: dict, 格式为 {i: {j: similarity}}，表示物品 i 与物品 j 的相似度
    """
    # 构建物品-用户倒排表
    item_users = defaultdict(set)
    for user, items in user_item.items():
        for i in items:
            item_users[i].add(user)
    
    # 共现矩阵，用于统计同时出现在同一用户行为中的物品对次数
    co_occurrence = defaultdict(lambda: defaultdict(int))
    # 统计每个物品被交互的次数（即用户数）
    item_count = {i: len(users) for i, users in item_users.items()}
    
    # 遍历每个用户的交互物品，更新共现矩阵
    for user, items in user_item.items():
        items = list(items)
        for i in range(len(items)):
            for j in range(i + 1, len(items)):
                item_i = items[i]
                item_j = items[j]
                co_occurrence[item_i][item_j] += 1
                co_occurrence[item_j][item_i] += 1  # 对称关系

                #对于ItemCF-IUF,只需要 += 1 / math.log(1+len(items))

    # 根据共现矩阵计算余弦相似度
    item_similarity = defaultdict(dict)
    for i, related_items in co_occurrence.items():
        for j, co_count in related_items.items():
            # 注意：如果某个物品没有交互记录，则 item_count[i] 为 0，通常不会出现这种情况
            sim = co_count / math.sqrt(item_count[i] * item_count[j])
            item_similarity[i][j] = sim

    # ---------------------------
    # 归一化处理：对每个物品 i，将与其它物品的相似度除以其最大相似度
    # 参考: George Karypis 的 "Evaluation of Item-based Top-N Recommendation Algorithms"
    # ---------------------------
    for i, sim_dict in item_similarity.items():
        max_sim = max(sim_dict.values(), default=0)
        if max_sim > 0:
            for j in sim_dict:
                sim_dict[j] /= max_sim

    return item_similarity

item_similarity_norm = calc_item_similarity_norm(user_item)

# %%
# 为方便查找，构造一个从 MovieID 到 Title 的字典
movie_titles = pd.Series(movies.Title.values,index=movies.MovieID).to_dict()

# 遍历物品相似度字典，打印出每个电影及其相似电影信息
print("物品相似度情况（仅显示前5个电影的相似度信息）：")
for idx, (movie_id, sim_dict) in enumerate(item_similarity.items()):
    if idx >= 5:  # 只显示前5个电影
        break
    title = movie_titles.get(movie_id, "Unknown")
    print(f"电影 {movie_id} - {title}:")
    # 遍历与该电影相似的其他电影
    for other_id, sim in sim_dict.items():
        other_title = movie_titles.get(other_id, "Unknown")
        print(f"    与电影 {other_id} - {other_title} 的相似度: {sim:.4f}")
    print()
# Out:
# 物品相似度情况（仅显示前5个电影的相似度信息）：
# 电影 1 - Toy Story (1995):
#     与电影 2692 - Run Lola Run (Lola rennt) (1998) 的相似度: 0.3015
#     与电影 1028 - Mary Poppins (1964) 的相似度: 0.3951
#     与电影 1029 - Dumbo (1941) 的相似度: 0.3416
#     与电影 1287 - Ben-Hur (1959) 的相似度: 0.2747
#     与电影 1545 - Ponette (1996) 的相似度: 0.0793
#     与电影 527 - Schindler's List (1993) 的相似度: 0.4418
#     与电影 914 - My Fair Lady (1964) 的相似度: 0.2764
#     与电影 531 - Secret Garden, The (1993) 的相似度: 0.2290
#     与电影 150 - Apollo 13 (1995) 的相似度: 0.4070
#     与电影 1566 - Hercules (1997) 的相似度: 0.3369
#     与电影 3105 - Awakenings (1990) 的相似度: 0.3002
#     与电影 2340 - Meet Joe Black (1998) 的相似度: 0.2098
#     与电影 1193 - One Flew Over the Cuckoo's Nest (1975) 的相似度: 0.3415
#     与电影 938 - Gigi (1958) 的相似度: 0.1467
#     与电影 1961 - Rain Man (1988) 的相似度: 0.3687
#     与电影 1836 - Last Days of Disco, The (1998) 的相似度: 0.1369
#     与电影 1197 - Princess Bride, The (1987) 的相似度: 0.4880
#     与电影 1962 - Driving Miss Daisy (1989) 的相似度: 0.2947
#     与电影 3114 - Toy Story 2 (1999) 的相似度: 0.5471
#     与电影 48 - Pocahontas (1995) 的相似度: 0.3042
#     与电影 2355 - Bug's Life, A (1998) 的相似度: 0.5038
#     与电影 1207 - To Kill a Mockingbird (1962) 的相似度: 0.3104
#     与电影 1721 - Titanic (1997) 的相似度: 0.3893
#     与电影 1097 - E.T. the Extra-Terrestrial (1982) 的相似度: 0.4555
#     与电影 2762 - Sixth Sense, The (1999) 的相似度: 0.4649
#     与电影 588 - Aladdin (1992) 的相似度: 0.5350
#     与电影 3408 - Erin Brockovich (2000) 的相似度: 0.3098
#     与电影 720 - Wallace & Gromit: The Best of Aardman Animation (1996) 的相似度: 0.2903
#     与电影 594 - Snow White and the Seven Dwarfs (1937) 的相似度: 0.3895
#     与电影 2398 - Miracle on 34th Street (1947) 的相似度: 0.2256
#     与电影 1246 - Dead Poets Society (1989) 的相似度: 0.3473
#     与电影 608 - Fargo (1996) 的相似度: 0.4492
#     与电影 2018 - Bambi (1942) 的相似度: 0.3550
#     与电影 2918 - Ferris Bueller's Day Off (1986) 的相似度: 0.4620
#     与电影 2791 - Airplane! (1980) 的相似度: 0.4319
#     与电影 745 - Close Shave, A (1995) 的相似度: 0.3240
#     与电影 2028 - Saving Private Ryan (1998) 的相似度: 0.4620
#     与电影 2797 - Big (1988) 的相似度: 0.4724
#     与电影 3186 - Girl, Interrupted (1999) 的相似度: 0.2043
#     与电影 1907 - Mulan (1998) 的相似度: 0.3516
#     与电影 2804 - Christmas Story, A (1983) 的相似度: 0.4079
#     与电影 1270 - Back to the Future (1985) 的相似度: 0.4930
#     与电影 2294 - Antz (1998) 的相似度: 0.3905
#     与电影 1022 - Cinderella (1950) 的相似度: 0.3371
#     与电影 2687 - Tarzan (1999) 的相似度: 0.3327
#     与电影 3072 - Moonstruck (1987) 的相似度: 0.3331
#     与电影 3074 - Jeremiah Johnson (1972) 的相似度: 0.1488
#     与电影 3717 - Gone in 60 Seconds (2000) 的相似度: 0.2325
#     与电影 1030 - Pete's Dragon (1977) 的相似度: 0.2700
#     与电影 1035 - Sound of Music, The (1965) 的相似度: 0.3090
#     与电影 1806 - Paulie (1998) 的相似度: 0.1949
#     与电影 3600 - Blue Hawaii (1961) 的相似度: 0.1038
#     与电影 1296 - Room with a View, A (1986) 的相似度: 0.2204
#     与电影 17 - Sense and Sensibility (1995) 的相似度: 0.2964
#     与电影 1043 - To Gillian on Her 37th Birthday (1996) 的相似度: 0.1537
#     与电影 912 - Casablanca (1942) 的相似度: 0.3451
#     与电影 2966 - Straight Story, The (1999) 的相似度: 0.1830
#     与电影 1688 - Anastasia (1997) 的相似度: 0.2501
#     与电影 920 - Gone with the Wind (1939) 的相似度: 0.3200
#     与电影 1947 - West Side Story (1961) 的相似度: 0.2996
#     与电影 1569 - My Best Friend's Wedding (1997) 的相似度: 0.3608
#     与电影 2081 - Little Mermaid, The (1989) 的相似度: 0.4399
#     与电影 2082 - Mighty Ducks, The (1992) 的相似度: 0.2820
#     与电影 1188 - Strictly Ballroom (1992) 的相似度: 0.2977
#     与电影 1441 - Benny & Joon (1993) 的相似度: 0.2895
#     与电影 2469 - Peggy Sue Got Married (1986) 的相似度: 0.2723
#     与电影 34 - Babe (1995) 的相似度: 0.4941
#     与电影 296 - Pulp Fiction (1994) 的相似度: 0.4617
#     与电影 3753 - Patriot, The (2000) 的相似度: 0.2987
#     与电影 3624 - Shanghai Noon (2000) 的相似度: 0.2579
#     与电影 3501 - Murphy's Romance (1985) 的相似度: 0.1788
#     与电影 2100 - Splash (1984) 的相似度: 0.4109
#     与电影 569 - Little Big League (1994) 的相似度: 0.1608
#     与电影 1210 - Star Wars: Episode VI - Return of the Jedi (1983) 的相似度: 0.4663
#     与电影 1088 - Dirty Dancing (1987) 的相似度: 0.2843
#     与电影 3524 - Arthur (1981) 的相似度: 0.2704
#     与电影 838 - Emma (1996) 的相似度: 0.2558
#     与电影 199 - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964) 的相似度: 0.0946
#     与电影 2506 - Other Sister, The (1999) 的相似度: 0.1475
#     与电影 1101 - Top Gun (1986) 的相似度: 0.3662
#     与电影 590 - Dances with Wolves (1990) 的相似度: 0.4275
#     与电影 3534 - 28 Days (2000) 的相似度: 0.1825
#     与电影 3536 - Keeping the Faith (2000) 的相似度: 0.2460
#     与电影 597 - Pretty Woman (1990) 的相似度: 0.3934
#     与电影 2006 - Mask of Zorro, The (1998) 的相似度: 0.3426
#     与电影 2396 - Shakespeare in Love (1998) 的相似度: 0.4946
#     与电影 3682 - Magnum Force (1973) 的相似度: 0.1708
#     与电影 1380 - Grease (1978) 的相似度: 0.3564
#     与电影 3685 - Prizzi's Honor (1985) 的相似度: 0.2525
#     与电影 2406 - Romancing the Stone (1984) 的相似度: 0.3937
#     与电影 364 - Lion King, The (1994) 的相似度: 0.4728
#     与电影 1007 - Apple Dumpling Gang, The (1975) 的相似度: 0.1921
#     与电影 368 - Maverick (1994) 的相似度: 0.3421
#     与电影 2802 - Tequila Sunrise (1988) 的相似度: 0.2056
#     与电影 3699 - Starman (1984) 的相似度: 0.3051
#     与电影 377 - Speed (1994) 的相似度: 0.4268
#     与电影 3578 - Gladiator (2000) 的相似度: 0.3810
#     与电影 383 - Wyatt Earp (1994) 的相似度: 0.1891
#     与电影 4 - Waiting to Exhale (1995) 的相似度: 0.1677
#     与电影 2571 - Matrix, The (1999) 的相似度: 0.4867
#     与电影 524 - Rudy (1993) 的相似度: 0.2403
#     与电影 14 - Nixon (1995) 的相似度: 0.1392
#     与电影 16 - Casino (1995) 的相似度: 0.2757
#     与电影 24 - Powder (1995) 的相似度: 0.2338
#     与电影 25 - Leaving Las Vegas (1995) 的相似度: 0.3148
#     与电影 538 - Six Degrees of Separation (1993) 的相似度: 0.2170
#     与电影 1059 - William Shakespeare's Romeo and Juliet (1996) 的相似度: 0.2805
#     与电影 3107 - Backdraft (1991) 的相似度: 0.3132
#     与电影 1573 - Face/Off (1997) 的相似度: 0.3885
#     与电影 36 - Dead Man Walking (1995) 的相似度: 0.3167
#     与电影 2600 - eXistenZ (1999) 的相似度: 0.1873
#     与电影 42 - Dead Presidents (1995) 的相似度: 0.1747
#     与电影 555 - True Romance (1993) 的相似度: 0.2765
#     与电影 1580 - Men in Black (1997) 的相似度: 0.4807
#     与电影 562 - Welcome to the Dollhouse (1995) 的相似度: 0.2749
#     与电影 1589 - Cop Land (1997) 的相似度: 0.2483
#     与电影 58 - Postino, Il (The Postman) (1994) 的相似度: 0.2069
#     与电影 73 - Misérables, Les (1995) 的相似度: 0.1613
#     与电影 3147 - Green Mile, The (1999) 的相似度: 0.3593
#     与电影 3148 - Cider House Rules, The (1999) 的相似度: 0.2536
#     与电影 589 - Terminator 2: Judgment Day (1991) 的相似度: 0.4578
#     与电影 3155 - Anna and the King (1999) 的相似度: 0.1564
#     与电影 1621 - Soul Food (1997) 的相似度: 0.1350
#     与电影 1120 - People vs. Larry Flynt, The (1996) 的相似度: 0.2594
#     与电影 3173 - Any Given Sunday (1999) 的相似度: 0.2087
#     与电影 1639 - Chasing Amy (1997) 的相似度: 0.3521
#     与电影 105 - Bridges of Madison County, The (1995) 的相似度: 0.2096
#     与电影 110 - Braveheart (1995) 的相似度: 0.4359
#     与电影 111 - Taxi Driver (1976) 的相似度: 0.3213
#     与电影 1660 - Eve's Bayou (1997) 的相似度: 0.1632
#     与电影 2686 - Red Violin, The (Le Violon rouge) (1998) 的相似度: 0.2200
#     与电影 1673 - Boogie Nights (1997) 的相似度: 0.3240
#     与电影 650 - Moll Flanders (1996) 的相似度: 0.1019
#     与电影 2699 - Arachnophobia (1990) 的相似度: 0.3436
#     与电影 3213 - Batman: Mask of the Phantasm (1993) 的相似度: 0.2257
#     与电影 2702 - Summer of Sam (1999) 的相似度: 0.1799
#     与电影 1678 - Joy Luck Club, The (1993) 的相似度: 0.2515
#     与电影 1682 - Truman Show, The (1998) 的相似度: 0.3898
#     与电影 151 - Rob Roy (1995) 的相似度: 0.2779
#     与电影 2712 - Eyes Wide Shut (1999) 的相似度: 0.2678
#     与电影 161 - Crimson Tide (1995) 的相似度: 0.3176
#     与电影 163 - Desperado (1995) 的相似度: 0.2551
#     与电影 1701 - Deconstructing Harry (1997) 的相似度: 0.2315
#     与电影 1704 - Good Will Hunting (1997) 的相似度: 0.4407
#     与电影 3246 - Malcolm X (1992) 的相似度: 0.2652
#     与电影 1711 - Midnight in the Garden of Good and Evil (1997) 的相似度: 0.2993
#     与电影 3250 - Alive (1993) 的相似度: 0.2317
#     与电影 3256 - Patriot Games (1992) 的相似度: 0.3440
#     与电影 3257 - Bodyguard, The (1992) 的相似度: 0.2591
#     与电影 3259 - Far and Away (1992) 的相似度: 0.2304
#     与电影 3260 - Howards End (1992) 的相似度: 0.2380
#     与电影 1213 - GoodFellas (1990) 的相似度: 0.3837
#     与电影 3265 - Hard-Boiled (Lashou shentan) (1992) 的相似度: 0.1903
#     与电影 1730 - Kundun (1997) 的相似度: 0.1516
#     与电影 3267 - Mariachi, El (1992) 的相似度: 0.2460
#     与电影 1735 - Great Expectations (1998) 的相似度: 0.1710
#     与电影 2268 - Few Good Men, A (1992) 的相似度: 0.3762
#     与电影 733 - Rock, The (1996) 的相似度: 0.3954
#     与电影 741 - Ghost in the Shell (Kokaku kidotai) (1995) 的相似度: 0.2252
#     与电影 2278 - Ronin (1998) 的相似度: 0.3011
#     与电影 1265 - Groundhog Day (1993) 的相似度: 0.5515
#     与电影 2291 - Edward Scissorhands (1990) 的相似度: 0.4066
#     与电影 2297 - What Dreams May Come (1998) 的相似度: 0.2339
#     与电影 1274 - Akira (1988) 的相似度: 0.2611
#     与电影 1277 - Cyrano de Bergerac (1990) 的相似度: 0.1798
#     与电影 253 - Interview with the Vampire (1994) 的相似度: 0.3056
#     与电影 265 - Like Water for Chocolate (Como agua para chocolate) (1992) 的相似度: 0.2647
#     与电影 266 - Legends of the Fall (1994) 的相似度: 0.2412
#     与电影 1801 - Man in the Iron Mask, The (1998) 的相似度: 0.2249
#     与电影 269 - My Crazy Life (Mi vida loca) (1993) 的相似度: 0.0998
#     与电影 2320 - Apt Pupil (1998) 的相似度: 0.1778
#     与电影 1810 - Primary Colors (1998) 的相似度: 0.2333
#     与电影 2324 - Life Is Beautiful (La Vita è bella) (1997) 的相似度: 0.3821
#     与电影 2329 - American History X (1998) 的相似度: 0.2997
#     与电影 282 - Nell (1994) 的相似度: 0.1946
#     与电影 2336 - Elizabeth (1998) 的相似度: 0.2813
#     与电影 288 - Natural Born Killers (1994) 的相似度: 0.2967
#     与电影 2858 - American Beauty (1999) 的相似度: 0.4605
#     与电影 1840 - He Got Game (1998) 的相似度: 0.1536
#     与电影 3386 - JFK (1991) 的相似度: 0.3152
#     与电影 1357 - Shine (1996) 的相似度: 0.2455
#     与电影 337 - What's Eating Gilbert Grape (1993) 的相似度: 0.3283
#     与电影 345 - Adventures of Priscilla, Queen of the Desert, The (1994) 的相似度: 0.2435
#     与电影 349 - Clear and Present Danger (1994) 的相似度: 0.3450
#     与电影 2908 - Boys Don't Cry (1999) 的相似度: 0.2581
#     与电影 3425 - Mo' Better Blues (1990) 的相似度: 0.1239
#     与电影 2916 - Total Recall (1990) 的相似度: 0.4329
#     与电影 1393 - Jerry Maguire (1996) 的相似度: 0.4193
#     与电影 2427 - Thin Red Line, The (1998) 的相似度: 0.2765
#     与电影 1916 - Buffalo 66 (1998) 的相似度: 0.2309
#     与电影 2429 - Mighty Joe Young (1998) 的相似度: 0.2195
#     与电影 1411 - Hamlet (1996) 的相似度: 0.2240
#     与电影 393 - Street Fighter (1994) 的相似度: 0.1280
#     与电影 2442 - Hilary and Jackie (1998) 的相似度: 0.1246
#     与电影 908 - North by Northwest (1959) 的相似度: 0.3197
#     与电影 3481 - High Fidelity (2000) 的相似度: 0.3404
#     与电影 3500 - Mr. Saturday Night (1992) 的相似度: 0.1763
#     与电影 1466 - Donnie Brasco (1997) 的相似度: 0.2810
#     与电影 2490 - Payback (1999) 的相似度: 0.2625
#     与电影 3006 - Insider, The (1999) 的相似度: 0.3125
#     与电影 1476 - Private Parts (1997) 的相似度: 0.3007
#     与电影 454 - Firm, The (1993) 的相似度: 0.3221
#     与电影 3528 - Prince of Tides, The (1991) 的相似度: 0.1962
#     与电影 1488 - Devil's Own, The (1997) 的相似度: 0.1904
#     与电影 465 - Heaven & Earth (1993) 的相似度: 0.0937
#     与电影 476 - Inkwell, The (1994) 的相似度: 0.0730
#     与电影 480 - Jurassic Park (1993) 的相似度: 0.4530
#     与电影 2541 - Cruel Intentions (1999) 的相似度: 0.2168
#     与电影 506 - Orlando (1993) 的相似度: 0.1381
#     与电影 508 - Philadelphia (1993) 的相似度: 0.2757
#     与电影 510 - Poetic Justice (1993) 的相似度: 0.0840
#     与电影 1552 - Con Air (1997) 的相似度: 0.3554
#     与电影 529 - Searching for Bobby Fischer (1993) 的相似度: 0.3135
#     与电影 1060 - Swingers (1996) 的相似度: 0.3582
#     与电影 2599 - Election (1999) 的相似度: 0.4029
#     与电影 3623 - Mission: Impossible 2 (2000) 的相似度: 0.3254
#     与电影 47 - Seven (Se7en) (1995) 的相似度: 0.3904
#     与电影 1584 - Contact (1997) 的相似度: 0.4187
#     与电影 50 - Usual Suspects, The (1995) 的相似度: 0.4272
#     与电影 1617 - L.A. Confidential (1997) 的相似度: 0.4276
#     与电影 3160 - Magnolia (1999) 的相似度: 0.2913
#     与电影 3178 - Hurricane, The (1999) 的相似度: 0.2543
#     与电影 1653 - Gattaca (1997) 的相似度: 0.3486
#     与电影 2166 - Return to Paradise (1998) 的相似度: 0.1382
#     与电影 1148 - Wrong Trousers, The (1993) 的相似度: 0.3882
#     与电影 1669 - Tango Lesson, The (1997) 的相似度: 0.0718
#     与电影 162 - Crumb (1994) 的相似度: 0.2491
#     与电影 3751 - Chicken Run (2000) 的相似度: 0.3926
#     与电影 3255 - League of Their Own, A (1992) 的相似度: 0.4394
#     与电影 1221 - Godfather: Part II, The (1974) 的相似度: 0.3556
#     与电影 3270 - Cutting Edge, The (1992) 的相似度: 0.1741
#     与电影 1223 - Grand Day Out, A (1992) 的相似度: 0.3039
#     与电影 3793 - X-Men (2000) 的相似度: 0.3677
#     与电影 1233 - Boat, The (Das Boot) (1981) 的相似度: 0.2727
#     与电影 223 - Clerks (1994) 的相似度: 0.4110
#     与电影 3298 - Boiler Room (2000) 的相似度: 0.2148
#     与电影 3301 - Whole Nine Yards, The (2000) 的相似度: 0.2558
#     与电影 1777 - Wedding Singer, The (1998) 的相似度: 0.4179
#     与电影 3826 - Hollow Man (2000) 的相似度: 0.2018
#     与电影 1784 - As Good As It Gets (1997) 的相似度: 0.4506
#     与电影 2302 - My Cousin Vinny (1992) 的相似度: 0.4260
#     与电影 778 - Trainspotting (1996) 的相似度: 0.3166
#     与电影 1307 - When Harry Met Sally... (1989) 的相似度: 0.4409
#     与电影 1310 - Hype! (1996) 的相似度: 0.0802
#     与电影 805 - Time to Kill, A (1996) 的相似度: 0.2209
#     与电影 300 - Quiz Show (1994) 的相似度: 0.3196
#     与电影 318 - Shawshank Redemption, The (1994) 的相似度: 0.4636
#     与电影 1343 - Cape Fear (1991) 的相似度: 0.2989
#     与电影 2890 - Three Kings (1999) 的相似度: 0.3856
#     与电影 1356 - Star Trek: First Contact (1996) 的相似度: 0.3750
#     与电影 3916 - Remember the Titans (2000) 的相似度: 0.2104
#     与电影 1358 - Sling Blade (1996) 的相似度: 0.3584
#     与电影 861 - Supercop (1992) 的相似度: 0.2230
#     与电影 3948 - Meet the Parents (2000) 的相似度: 0.2817
#     与电影 367 - Mask, The (1994) 的相似度: 0.4358
#     与电影 1912 - Out of Sight (1998) 的相似度: 0.3303
#     与电影 3452 - Romeo Must Die (2000) 的相似度: 0.1727
#     与电影 1921 - Pi (1998) 的相似度: 0.2767
#     与电影 1923 - There's Something About Mary (1998) 的相似度: 0.4870
#     与电影 2959 - Fight Club (1999) 的相似度: 0.3791
#     与电影 3484 - Skulls, The (2000) 的相似度: 0.1625
#     与电影 412 - Age of Innocence, The (1993) 的相似度: 0.1886
#     与电影 1446 - Kolya (1996) 的相似度: 0.1447
#     与电影 428 - Bronx Tale, A (1993) 的相似度: 0.2012
#     与电影 457 - Fugitive, The (1993) 的相似度: 0.4680
#     与电影 994 - Big Night (1996) 的相似度: 0.2445
#     与电影 2 - Jumanji (1995) 的相似度: 0.3412
#     与电影 2049 - Happiest Millionaire, The (1967) 的相似度: 0.0541
#     与电影 2054 - Honey, I Shrunk the Kids (1989) 的相似度: 0.3839
#     与电影 7 - Sabrina (1995) 的相似度: 0.2877
#     与电影 2067 - Doctor Zhivago (1965) 的相似度: 0.2299
#     与电影 2072 - 'burbs, The (1989) 的相似度: 0.2197
#     与电影 2077 - Journey of Natty Gann, The (1985) 的相似度: 0.1637
#     与电影 2078 - Jungle Book, The (1967) 的相似度: 0.3684
#     与电影 2080 - Lady and the Tramp (1955) 的相似度: 0.3945
#     与电影 32 - Twelve Monkeys (1995) 的相似度: 0.4046
#     与电影 2087 - Peter Pan (1953) 的相似度: 0.3365
#     与电影 2090 - Rescuers, The (1977) 的相似度: 0.2355
#     与电影 2091 - Return from Witch Mountain (1978) 的相似度: 0.1779
#     与电影 2093 - Return to Oz (1985) 的相似度: 0.1986
#     与电影 2094 - Rocketeer, The (1991) 的相似度: 0.3046
#     与电影 2096 - Sleeping Beauty (1959) 的相似度: 0.3264
#     与电影 2105 - Tron (1982) 的相似度: 0.3303
#     与电影 2108 - L.A. Story (1991) 的相似度: 0.3659
#     与电影 2109 - Jerk, The (1979) 的相似度: 0.3171
#     与电影 62 - Mr. Holland's Opus (1995) 的相似度: 0.2943
#     与电影 2111 - Man with Two Brains, The (1983) 的相似度: 0.2462
#     与电影 2115 - Indiana Jones and the Temple of Doom (1984) 的相似度: 0.3710
#     与电影 2124 - Addams Family, The (1991) 的相似度: 0.3772
#     与电影 2125 - Ever After: A Cinderella Story (1998) 的相似度: 0.2576
#     与电影 2133 - Adventures in Babysitting (1987) 的相似度: 0.3006
#     与电影 2135 - Doctor Dolittle (1967) 的相似度: 0.1829
#     与电影 2137 - Charlotte's Web (1973) 的相似度: 0.3358
#     与电影 2138 - Watership Down (1978) 的相似度: 0.2131
#     与电影 2140 - Dark Crystal, The (1982) 的相似度: 0.2899
#     与电影 104 - Happy Gilmore (1996) 的相似度: 0.3630
#     与电影 2161 - NeverEnding Story, The (1984) 的相似度: 0.3305
#     与电影 116 - Anne Frank Remembered (1995) 的相似度: 0.0605
#     与电影 2174 - Beetlejuice (1988) 的相似度: 0.4605
#     与电影 2193 - Willow (1988) 的相似度: 0.3160
#     与电影 153 - Batman Forever (1995) 的相似度: 0.3491
#     与电影 180 - Mallrats (1995) 的相似度: 0.3244
#     与电影 186 - Nine Months (1995) 的相似度: 0.2134
#     与电影 2252 - Hero (1992) 的相似度: 0.1960
#     与电影 208 - Waterworld (1995) 的相似度: 0.3062
#     与电影 248 - Houseguest (1994) 的相似度: 0.1572
#     与电影 2300 - Producers, The (1968) 的相似度: 0.2865
#     与电影 260 - Star Wars: Episode IV - A New Hope (1977) 的相似度: 0.4797
#     与电影 2312 - Children of a Lesser God (1986) 的相似度: 0.2166
#     与电影 2316 - Practical Magic (1998) 的相似度: 0.1817
#     与电影 2321 - Pleasantville (1998) 的相似度: 0.4469
#     与电影 275 - Mixed Nuts (1994) 的相似度: 0.1390
#     与电影 316 - Stargate (1994) 的相似度: 0.3453
#     与电影 317 - Santa Clause, The (1994) 的相似度: 0.3523
#     与电影 2371 - Fletch (1985) 的相似度: 0.3238
#     与电影 2375 - Money Pit, The (1986) 的相似度: 0.2544
#     与电影 329 - Star Trek: Generations (1994) 的相似度: 0.3474
#     与电影 2378 - Police Academy (1984) 的相似度: 0.2710
#     与电影 333 - Tommy Boy (1995) 的相似度: 0.3005
#     与电影 339 - While You Were Sleeping (1995) 的相似度: 0.3391
#     与电影 344 - Ace Ventura: Pet Detective (1994) 的相似度: 0.3605
#     与电影 351 - Corrina, Corrina (1994) 的相似度: 0.2015
#     与电影 2399 - Santa Claus: The Movie (1985) 的相似度: 0.1660
#     与电影 356 - Forrest Gump (1994) 的相似度: 0.5082
#     与电影 357 - Four Weddings and a Funeral (1994) 的相似度: 0.4245
#     与电影 2405 - Jewel of the Nile, The (1985) 的相似度: 0.3074
#     与电影 2407 - Cocoon (1985) 的相似度: 0.3594
#     与电影 2423 - Christmas Vacation (1989) 的相似度: 0.3132
#     与电影 2431 - Patch Adams (1998) 的相似度: 0.2717
#     与电影 2436 - Tea with Mussolini (1999) 的相似度: 0.1256
#     与电影 2453 - Boy Who Could Fly, The (1986) 的相似度: 0.1541
#     与电影 2470 - Crocodile Dundee (1986) 的相似度: 0.3616
#     与电影 435 - Coneheads (1993) 的相似度: 0.2886
#     与电影 2496 - Blast from the Past (1999) 的相似度: 0.2677
#     与电影 2497 - Message in a Bottle (1999) 的相似度: 0.1333
#     与电影 2498 - My Favorite Martian (1999) 的相似度: 0.1540
#     与电影 2501 - October Sky (1999) 的相似度: 0.2814
#     与电影 2529 - Planet of the Apes (1968) 的相似度: 0.3345
#     与电影 520 - Robin Hood: Men in Tights (1993) 的相似度: 0.2764
#     与电影 539 - Sleepless in Seattle (1993) 的相似度: 0.3970
#     与电影 541 - Blade Runner (1982) 的相似度: 0.3963
#     与电影 542 - Son in Law (1993) 的相似度: 0.1951
#     与电影 543 - So I Married an Axe Murderer (1993) 的相似度: 0.3390
#     与电影 551 - Nightmare Before Christmas, The (1993) 的相似度: 0.4288
#     与电影 2622 - Midsummer Night's Dream, A (1999) 的相似度: 0.2285
#     与电影 586 - Home Alone (1990) 的相似度: 0.3677
#     与电影 587 - Ghost (1990) 的相似度: 0.4240
#     与电影 2640 - Superman (1978) 的相似度: 0.3718
#     与电影 595 - Beauty and the Beast (1991) 的相似度: 0.4644
#     与电影 596 - Pinocchio (1940) 的相似度: 0.3491
#     与电影 2657 - Rocky Horror Picture Show, The (1975) 的相似度: 0.3558
#     与电影 2662 - War of the Worlds, The (1953) 的相似度: 0.2286
#     与电影 2693 - Trekkies (1997) 的相似度: 0.1961
#     与电影 648 - Mission: Impossible (1996) 的相似度: 0.4072
#     与电影 653 - Dragonheart (1996) 的相似度: 0.2801
#     与电影 2716 - Ghostbusters (1984) 的相似度: 0.4569
#     与电影 2717 - Ghostbusters II (1989) 的相似度: 0.3124
#     与电影 671 - Mystery Science Theater 3000: The Movie (1996) 的相似度: 0.2508
#     与电影 2746 - Little Shop of Horrors (1986) 的相似度: 0.3408
#     与电影 2770 - Bowfinger (1999) 的相似度: 0.3222
#     与电影 743 - Spy Hard (1996) 的相似度: 0.1729
#     与电影 2795 - Vacation (1983) 的相似度: 0.3262
#     与电影 765 - Jack (1996) 的相似度: 0.1941
#     与电影 2826 - 13th Warrior, The (1999) 的相似度: 0.2411
#     与电影 780 - Independence Day (ID4) (1996) 的相似度: 0.4299
#     与电影 784 - Cable Guy, The (1996) 的相似度: 0.2858
#     与电影 802 - Phenomenon (1996) 的相似度: 0.2578
#     与电影 2863 - Hard Day's Night, A (1964) 的相似度: 0.2457
#     与电影 2872 - Excalibur (1981) 的相似度: 0.2732
#     与电影 2874 - Pajama Game, The (1957) 的相似度: 0.1016
#     与电影 830 - First Wives Club, The (1996) 的相似度: 0.2358
#     与电影 858 - Godfather, The (1972) 的相似度: 0.4010
#     与电影 2946 - Help! (1965) 的相似度: 0.2020
#     与电影 899 - Singin' in the Rain (1952) 的相似度: 0.2901
#     与电影 2948 - From Russia with Love (1963) 的相似度: 0.2709
#     与电影 902 - Breakfast at Tiffany's (1961) 的相似度: 0.2451
#     与电影 904 - Rear Window (1954) 的相似度: 0.3275
#     与电影 915 - Sabrina (1954) 的相似度: 0.2121
#     与电影 916 - Roman Holiday (1953) 的相似度: 0.2190
#     与电影 918 - Meet Me in St. Louis (1944) 的相似度: 0.1319
#     与电影 2967 - Bad Seed, The (1956) 的相似度: 0.0938
#     与电影 2968 - Time Bandits (1981) 的相似度: 0.3256
#     与电影 923 - Citizen Kane (1941) 的相似度: 0.3240
#     与电影 924 - 2001: A Space Odyssey (1968) 的相似度: 0.3766
#     与电影 932 - Affair to Remember, An (1957) 的相似度: 0.1256
#     与电影 943 - Ghost and Mrs. Muir, The (1947) 的相似度: 0.1222
#     与电影 2997 - Being John Malkovich (1999) 的相似度: 0.4330
#     与电影 953 - It's a Wonderful Life (1946) 的相似度: 0.3266
#     与电影 954 - Mr. Smith Goes to Washington (1939) 的相似度: 0.2103
#     与电影 963 - Inspector General, The (1949) 的相似度: 0.0874
#     与电影 969 - African Queen, The (1951) 的相似度: 0.2662
#     与电影 3034 - Robin Hood (1973) 的相似度: 0.2897
#     与电影 3035 - Mister Roberts (1955) 的相似度: 0.2169
#     与电影 3037 - Little Big Man (1970) 的相似度: 0.2517
#     与电影 3039 - Trading Places (1983) 的相似度: 0.3761
#     与电影 1009 - Escape to Witch Mountain (1975) 的相似度: 0.2233
#     与电影 1015 - Homeward Bound: The Incredible Journey (1993) 的相似度: 0.2146
#     与电影 1016 - Shaggy Dog, The (1959) 的相似度: 0.1714
#     与电影 3066 - Tora! Tora! Tora! (1970) 的相似度: 0.1745
#     与电影 1019 - 20,000 Leagues Under the Sea (1954) 的相似度: 0.2249
#     与电影 1020 - Cool Runnings (1993) 的相似度: 0.3099
#     与电影 1023 - Winnie the Pooh and the Blustery Day (1968) 的相似度: 0.2344
#     与电影 1032 - Alice in Wonderland (1951) 的相似度: 0.3150
#     与电影 3086 - March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland) (1934) 的相似度: 0.0887
#     与电影 3087 - Scrooged (1988) 的相似度: 0.3284
#     与电影 1042 - That Thing You Do! (1996) 的相似度: 0.3423
#     与电影 3095 - Grapes of Wrath, The (1940) 的相似度: 0.2246
#     与电影 3097 - Shop Around the Corner, The (1940) 的相似度: 0.1626
#     与电影 3099 - Shampoo (1975) 的相似度: 0.1769
#     与电影 3100 - River Runs Through It, A (1992) 的相似度: 0.2851
#     与电影 1073 - Willy Wonka and the Chocolate Factory (1971) 的相似度: 0.4331
#     与电影 1079 - Fish Called Wanda, A (1988) 的相似度: 0.4429
#     与电影 1080 - Monty Python's Life of Brian (1979) 的相似度: 0.3782
#     与电影 1084 - Bonnie and Clyde (1967) 的相似度: 0.2507
#     与电影 1091 - Weekend at Bernie's (1989) 的相似度: 0.2613
#     与电影 1104 - Streetcar Named Desire, A (1951) 的相似度: 0.2259
#     与电影 3153 - 7th Voyage of Sinbad, The (1958) 的相似度: 0.1437
#     与电影 1124 - On Golden Pond (1981) 的相似度: 0.2273
#     与电影 1125 - Return of the Pink Panther, The (1974) 的相似度: 0.2256
#     与电影 3174 - Man on the Moon (1999) 的相似度: 0.2883
#     与电影 1127 - Abyss, The (1989) 的相似度: 0.3636
#     与电影 3175 - Galaxy Quest (1999) 的相似度: 0.4141
#     与电影 1129 - Escape from New York (1981) 的相似度: 0.2874
#     与电影 1135 - Private Benjamin (1980) 的相似度: 0.2752
#     与电影 1136 - Monty Python and the Holy Grail (1974) 的相似度: 0.4641
#     与电影 3189 - My Dog Skip (1999) 的相似度: 0.1782
#     与电影 3198 - Papillon (1973) 的相似度: 0.1772
#     与电影 1196 - Star Wars: Episode V - The Empire Strikes Back (1980) 的相似度: 0.4799
#     与电影 3247 - Sister Act (1992) 的相似度: 0.3654
#     与电影 1200 - Aliens (1986) 的相似度: 0.4125
#     与电影 1201 - Good, The Bad and The Ugly, The (1966) 的相似度: 0.2960
#     与电影 1203 - 12 Angry Men (1957) 的相似度: 0.2427
#     与电影 3252 - Scent of a Woman (1992) 的相似度: 0.2526
#     与电影 3254 - Wayne's World 2 (1993) 的相似度: 0.2966
#     与电影 1214 - Alien (1979) 的相似度: 0.4117
#     与电影 1215 - Army of Darkness (1993) 的相似度: 0.3075
#     与电影 3264 - Buffy the Vampire Slayer (1992) 的相似度: 0.2931
#     与电影 1220 - Blues Brothers, The (1980) 的相似度: 0.3910
#     与电影 1225 - Amadeus (1984) 的相似度: 0.3489
#     与电影 1230 - Annie Hall (1977) 的相似度: 0.3185
#     与电影 1234 - Sting, The (1973) 的相似度: 0.3745
#     与电影 1240 - Terminator, The (1984) 的相似度: 0.4435
#     与电影 1247 - Graduate, The (1967) 的相似度: 0.3407
#     与电影 3296 - To Sir with Love (1967) 的相似度: 0.1747
#     与电影 1250 - Bridge on the River Kwai, The (1957) 的相似度: 0.2962
#     与电影 1252 - Chinatown (1974) 的相似度: 0.3009
#     与电影 1253 - Day the Earth Stood Still, The (1951) 的相似度: 0.2146
#     与电影 1254 - Treasure of the Sierra Madre, The (1948) 的相似度: 0.2054
#     与电影 1256 - Duck Soup (1933) 的相似度: 0.2675
#     与电影 1257 - Better Off Dead... (1985) 的相似度: 0.2904
#     与电影 1259 - Stand by Me (1986) 的相似度: 0.4262
#     与电影 3309 - Dog's Life, A (1920) 的相似度: 0.0602
#     与电影 1269 - Arsenic and Old Lace (1944) 的相似度: 0.2577
#     与电影 1271 - Fried Green Tomatoes (1991) 的相似度: 0.2845
#     与电影 1276 - Cool Hand Luke (1967) 的相似度: 0.3191
#     与电影 1282 - Fantasia (1940) 的相似度: 0.4050
#     与电影 1283 - High Noon (1952) 的相似度: 0.1962
#     与电影 1291 - Indiana Jones and the Last Crusade (1989) 的相似度: 0.4301
#     与电影 1292 - Being There (1979) 的相似度: 0.2919
#     与电影 1293 - Gandhi (1982) 的相似度: 0.2695
#     与电影 1294 - M*A*S*H (1970) 的相似度: 0.3736
#     与电影 3347 - Never Cry Wolf (1983) 的相似度: 0.1774
#     与电影 1302 - Field of Dreams (1989) 的相似度: 0.3412
#     与电影 3358 - Defending Your Life (1991) 的相似度: 0.2828
#     与电影 3359 - Breaking Away (1979) 的相似度: 0.2326
#     与电影 1320 - Alien³ (1992) 的相似度: 0.3158
#     与电影 1339 - Bram Stoker's Dracula (1992) 的相似度: 0.3057
#     与电影 3388 - Harry and the Hendersons (1987) 的相似度: 0.2413
#     与电影 1345 - Carrie (1976) 的相似度: 0.2654
#     与电影 1371 - Star Trek: The Motion Picture (1979) 的相似度: 0.3328
#     与电影 1372 - Star Trek VI: The Undiscovered Country (1991) 的相似度: 0.3341
#     与电影 1374 - Star Trek: The Wrath of Khan (1982) 的相似度: 0.3707
#     与电影 1375 - Star Trek III: The Search for Spock (1984) 的相似度: 0.3200
#     与电影 1376 - Star Trek IV: The Voyage Home (1986) 的相似度: 0.3636
#     与电影 1377 - Batman Returns (1992) 的相似度: 0.3863
#     与电影 1387 - Jaws (1975) 的相似度: 0.4091
#     与电影 3438 - Teenage Mutant Ninja Turtles (1990) 的相似度: 0.3041
#     与电影 3439 - Teenage Mutant Ninja Turtles II: The Secret of the Ooze (1991) 的相似度: 0.2226
#     与电影 1394 - Raising Arizona (1987) 的相似度: 0.4299
#     与电影 3447 - Good Earth, The (1937) 的相似度: 0.0889
#     与电影 3451 - Guess Who's Coming to Dinner (1967) 的相似度: 0.2196
#     与电影 1408 - Last of the Mohicans, The (1992) 的相似度: 0.3263
#     与电影 1409 - Michael (1996) 的相似度: 0.2586
#     与电影 3466 - Heart and Souls (1993) 的相似度: 0.2041
#     与电影 3471 - Close Encounters of the Third Kind (1977) 的相似度: 0.3910
#     与电影 3489 - Hook (1991) 的相似度: 0.3305
#     与电影 3525 - Bachelor Party (1984) 的相似度: 0.2554
#     与电影 1513 - Romy and Michele's High School Reunion (1997) 的相似度: 0.2881
#     与电影 1517 - Austin Powers: International Man of Mystery (1997) 的相似度: 0.4600
#     与电影 3591 - Mr. Mom (1983) 的相似度: 0.3174
#     与电影 1544 - Lost World: Jurassic Park, The (1997) 的相似度: 0.3413
#     与电影 3593 - Battlefield Earth (2000) 的相似度: 0.1488
#     与电影 3608 - Pee-wee's Big Adventure (1985) 的相似度: 0.3725
#     与电影 3629 - Gold Rush, The (1925) 的相似度: 0.1758
#     与电影 1583 - Simple Wish, A (1997) 的相似度: 0.0513
#     与电影 1586 - G.I. Jane (1997) 的相似度: 0.2612
#     与电影 3668 - Romeo and Juliet (1968) 的相似度: 0.1869
#     与电影 3671 - Blazing Saddles (1974) 的相似度: 0.3917
#     与电影 3675 - White Christmas (1954) 的相似度: 0.1704
#     与电影 1633 - Ulee's Gold (1997) 的相似度: 0.1792
#     与电影 3688 - Porky's (1981) 的相似度: 0.2491
#     与电影 3701 - Alien Nation (1988) 的相似度: 0.2507
#     与电影 3702 - Mad Max (1979) 的相似度: 0.3099
#     与电影 3703 - Mad Max 2 (a.k.a. The Road Warrior) (1981) 的相似度: 0.3079
#     与电影 3704 - Mad Max Beyond Thunderdome (1985) 的相似度: 0.2868
#     与电影 3723 - Hamlet (1990) 的相似度: 0.2126
#     与电影 1676 - Starship Troopers (1997) 的相似度: 0.3642
#     与电影 1756 - Prophecy II, The (1998) 的相似度: 0.0892
#     与电影 3809 - What About Bob? (1991) 的相似度: 0.3604
#     与电影 3812 - Everything You Always Wanted to Know About Sex (1972) 的相似度: 0.1748
#     与电影 3868 - Naked Gun: From the Files of Police Squad!, The (1988) 的相似度: 0.3185
#     与电影 3869 - Naked Gun 2 1/2: The Smell of Fear, The (1991) 的相似度: 0.2799
#     与电影 1831 - Lost in Space (1998) 的相似度: 0.3041
#     与电影 3928 - Abbott and Costello Meet Frankenstein (1948) 的相似度: 0.1419
#     与电影 1884 - Fear and Loathing in Las Vegas (1998) 的相似度: 0.2411
#     与电影 1918 - Lethal Weapon 4 (1998) 的相似度: 0.3120
#     与电影 1927 - All Quiet on the Western Front (1930) 的相似度: 0.1751
#     与电影 1948 - Tom Jones (1963) 的相似度: 0.1769
#     与电影 1954 - Rocky (1976) 的相似度: 0.3706
#     与电影 1959 - Out of Africa (1985) 的相似度: 0.2014
#     与电影 1967 - Labyrinth (1986) 的相似度: 0.2934
#     与电影 2000 - Lethal Weapon (1987) 的相似度: 0.4257
#     与电影 2001 - Lethal Weapon 2 (1989) 的相似度: 0.3546
#     与电影 2002 - Lethal Weapon 3 (1992) 的相似度: 0.3248
#     与电影 2003 - Gremlins (1984) 的相似度: 0.3724
#     与电影 2005 - Goonies, The (1985) 的相似度: 0.3398
#     与电影 2009 - Soylent Green (1973) 的相似度: 0.2094
#     与电影 2011 - Back to the Future Part II (1989) 的相似度: 0.3767
#     与电影 2012 - Back to the Future Part III (1990) 的相似度: 0.3951
#     与电影 2015 - Absent Minded Professor, The (1961) 的相似度: 0.2282
#     与电影 2021 - Dune (1984) 的相似度: 0.2979
#     与电影 2033 - Black Cauldron, The (1985) 的相似度: 0.1852
#     与电影 2040 - Computer Wore Tennis Shoes, The (1970) 的相似度: 0.1379
#     与电影 2041 - Condorman (1981) 的相似度: 0.1131
#     与电影 2043 - Darby O'Gill and the Little People (1959) 的相似度: 0.1522
#     与电影 2045 - Far Off Place, A (1993) 的相似度: 0.0807
#     与电影 2046 - Flight of the Navigator (1986) 的相似度: 0.2734
#     与电影 2047 - Gnome-Mobile, The (1967) 的相似度: 0.0616
#     与电影 1025 - Sword in the Stone, The (1963) 的相似度: 0.2853
#     与电影 2052 - Hocus Pocus (1993) 的相似度: 0.2059
#     与电影 1033 - Fox and the Hound, The (1981) 的相似度: 0.2540
#     与电影 10 - GoldenEye (1995) 的相似度: 0.3400
#     与电影 1036 - Die Hard (1988) 的相似度: 0.4193
#     与电影 2573 - Tango (1998) 的相似度: 0.0631
#     与电影 532 - Serial Mom (1994) 的相似度: 0.2312
#     与电影 26 - Othello (1995) 的相似度: 0.1329
#     与电影 1562 - Batman & Robin (1997) 的相似度: 0.3068
#     与电影 2076 - Blue Velvet (1986) 的相似度: 0.2591
#     与电影 29 - City of Lost Children, The (1995) 的相似度: 0.2251
#     与电影 2083 - Muppet Christmas Carol, The (1992) 的相似度: 0.2477
#     与电影 3108 - Fisher King, The (1991) 的相似度: 0.3742
#     与电影 546 - Super Mario Bros. (1993) 的相似度: 0.2358
#     与电影 2042 - D2: The Mighty Ducks (1994) 的相似度: 0.2100
#     与电影 552 - Three Musketeers, The (1993) 的相似度: 0.3034
#     与电影 44 - Mortal Kombat (1995) 的相似度: 0.2232
#     与电影 3635 - Spy Who Loved Me, The (1977) 的相似度: 0.2395
#     与电影 1587 - Conan the Barbarian (1982) 的相似度: 0.2744
#     与电影 3639 - Man with the Golden Gun, The (1974) 的相似度: 0.2006
#     与电影 1591 - Spawn (1997) 的相似度: 0.2557
#     与电影 2616 - Dick Tracy (1990) 的相似度: 0.3135
#     与电影 2617 - Mummy, The (1999) 的相似度: 0.3443
#     与电影 1089 - Reservoir Dogs (1992) 的相似度: 0.3842
#     与电影 2116 - Lord of the Rings, The (1978) 的相似度: 0.2531
#     与电影 1094 - Crying Game, The (1992) 的相似度: 0.3449
#     与电影 2123 - All Dogs Go to Heaven (1989) 的相似度: 0.2128
#     与电影 592 - Batman (1989) 的相似度: 0.4094
#     与电影 2141 - American Tail, An (1986) 的相似度: 0.3023
#     与电影 2142 - American Tail: Fievel Goes West, An (1991) 的相似度: 0.2261
#     与电影 2143 - Legend (1985) 的相似度: 0.2385
#     与电影 95 - Broken Arrow (1996) 的相似度: 0.2970
#     与电影 2145 - Pretty in Pink (1986) 的相似度: 0.3185
#     与电影 616 - Aristocats, The (1970) 的相似度: 0.2430
#     与电影 2153 - Avengers, The (1998) 的相似度: 0.1868
#     与电影 1643 - Mrs. Brown (Her Majesty, Mrs. Brown) (1997) 的相似度: 0.1418
#     与电影 3698 - Running Man, The (1987) 的相似度: 0.3224
#     与电影 1654 - FairyTale: A True Story (1997) 的相似度: 0.1168
#     与电影 2167 - Blade (1998) 的相似度: 0.3173
#     与电影 3705 - Bird on a Wire (1990) 的相似度: 0.2154
#     与电影 2701 - Wild Wild West (1999) 的相似度: 0.2938
#     与电影 2194 - Untouchables, The (1987) 的相似度: 0.3633
#     与电影 1683 - Wings of the Dove, The (1997) 的相似度: 0.1395
#     与电影 1690 - Alien: Resurrection (1997) 的相似度: 0.2863
#     与电影 1185 - My Left Foot (1989) 的相似度: 0.2259
#     与电影 1186 - Sex, Lies, and Videotape (1989) 的相似度: 0.2594
#     与电影 2723 - Mystery Men (1999) 的相似度: 0.3186
#     与电影 1702 - Flubber (1997) 的相似度: 0.2491
#     与电影 168 - First Knight (1995) 的相似度: 0.2364
#     与电影 1198 - Raiders of the Lost Ark (1981) 的相似度: 0.4643
#     与电影 2735 - Golden Child, The (1986) 的相似度: 0.2812
#     与电影 2739 - Color Purple, The (1985) 的相似度: 0.2430
#     与电影 3269 - Forever Young (1992) 的相似度: 0.2548
#     与电影 2763 - Thomas Crown Affair, The (1999) 的相似度: 0.3171
#     与电影 2764 - Thomas Crown Affair, The (1968) 的相似度: 0.1642
#     与电影 2253 - Toys (1992) 的相似度: 0.2910
#     与电影 1739 - 3 Ninjas: High Noon On Mega Mountain (1998) 的相似度: 0.0980
#     与电影 1242 - Glory (1989) 的相似度: 0.3477
#     与电影 736 - Twister (1996) 的相似度: 0.3840
#     与电影 737 - Barb Wire (1996) 的相似度: 0.1966
#     与电影 232 - Eat Drink Man Woman (1994) 的相似度: 0.1895
#     与电影 2807 - Universal Soldier: The Return (1999) 的相似度: 0.1039
#     与电影 249 - Immortal Beloved (1994) 的相似度: 0.1860
#     与电影 261 - Little Women (1994) 的相似度: 0.1989
#     与电影 262 - Little Princess, A (1995) 的相似度: 0.1870
#     与电影 1804 - Newton Boys, The (1998) 的相似度: 0.1398
#     与电影 1805 - Wild Things (1998) 的相似度: 0.2982
#     与电影 291 - Poison Ivy II (1995) 的相似度: 0.0791
#     与电影 292 - Outbreak (1995) 的相似度: 0.3178
#     与电影 3877 - Supergirl (1984) 的相似度: 0.1633
#     与电影 2348 - Sid and Nancy (1986) 的相似度: 0.2074
#     与电影 3889 - Highlander: Endgame (2000) 的相似度: 0.0983
#     与电影 313 - Swan Princess, The (1994) 的相似度: 0.1214
#     与电影 1344 - Cape Fear (1962) 的相似度: 0.1751
#     与电影 2370 - Emerald Forest, The (1985) 的相似度: 0.1342
#     与电影 3396 - Muppet Movie, The (1979) 的相似度: 0.3991
#     与电影 3397 - Great Muppet Caper, The (1981) 的相似度: 0.2891
#     与电影 3398 - Muppets Take Manhattan, The (1984) 的相似度: 0.2790
#     与电影 327 - Tank Girl (1995) 的相似度: 0.2238
#     与电影 839 - Crow: City of Angels, The (1996) 的相似度: 0.1278
#     与电影 2373 - Red Sonja (1985) 的相似度: 0.1877
#     与电影 3911 - Best in Show (2000) 的相似度: 0.2598
#     与电影 2893 - Plunkett & MaCleane (1999) 的相似度: 0.0744
#     与电影 2384 - Babe: Pig in the City (1998) 的相似度: 0.3307
#     与电影 1873 - Misérables, Les (1998) 的相似度: 0.1999
#     与电影 1876 - Deep Impact (1998) 的相似度: 0.3269
#     与电影 1367 - 101 Dalmatians (1996) 的相似度: 0.2665
#     与电影 2391 - Simple Plan, A (1998) 的相似度: 0.3102
#     与电影 1882 - Godzilla (1998) 的相似度: 0.2645
#     与电影 2394 - Prince of Egypt, The (1998) 的相似度: 0.2820
#     与电影 3418 - Thelma & Louise (1991) 的相似度: 0.3858
#     与电影 1378 - Young Guns (1988) 的相似度: 0.2942
#     与电影 353 - Crow, The (1994) 的相似度: 0.3035
#     与电影 2404 - Rambo III (1988) 的相似度: 0.1915
#     与电影 3440 - Teenage Mutant Ninja Turtles III (1993) 的相似度: 0.1860
#     与电影 2414 - Young Sherlock Holmes (1985) 的相似度: 0.2428
#     与电影 1396 - Sneakers (1992) 的相似度: 0.3757
#     与电影 2421 - Karate Kid, Part II, The (1986) 的相似度: 0.2854
#     与电影 2422 - Karate Kid III, The (1989) 的相似度: 0.2249
#     与电影 3448 - Good Morning, Vietnam (1987) 的相似度: 0.4022
#     与电影 380 - True Lies (1994) 的相似度: 0.4334
#     与电影 2947 - Goldfinger (1964) 的相似度: 0.3129
#     与电影 3461 - Lord of the Flies (1963) 的相似度: 0.1872
#     与电影 2951 - Fistful of Dollars, A (1964) 的相似度: 0.2246
#     与电影 2953 - Home Alone 2: Lost in New York (1992) 的相似度: 0.2662
#     与电影 2450 - Howard the Duck (1986) 的相似度: 0.2652
#     与电影 405 - Highlander III: The Sorcerer (1994) 的相似度: 0.1659
#     与电影 3479 - Ladyhawke (1985) 的相似度: 0.2505
#     与电影 919 - Wizard of Oz, The (1939) 的相似度: 0.4504
#     与电影 1956 - Ordinary People (1980) 的相似度: 0.2226
#     与电影 421 - Black Beauty (1994) 的相似度: 0.1342
#     与电影 2987 - Who Framed Roger Rabbit? (1988) 的相似度: 0.4345
#     与电影 940 - Adventures of Robin Hood, The (1938) 的相似度: 0.1972
#     与电影 2989 - For Your Eyes Only (1981) 的相似度: 0.2366
#     与电影 1968 - Breakfast Club, The (1985) 的相似度: 0.4247
#     与电影 2993 - Thunderball (1965) 的相似度: 0.2334
#     与电影 434 - Cliffhanger (1993) 的相似度: 0.3055
#     与电影 3526 - Parenthood (1989) 的相似度: 0.3616
#     与电影 3527 - Predator (1987) 的相似度: 0.3463
#     与电影 466 - Hot Shots! Part Deux (1993) 的相似度: 0.2917
#     与电影 1499 - Anaconda (1997) 的相似度: 0.2289
#     与电影 1500 - Grosse Pointe Blank (1997) 的相似度: 0.4499
#     与电影 475 - In the Name of the Father (1993) 的相似度: 0.2026
#     与电影 2014 - Freaky Friday (1977) 的相似度: 0.1948
#     与电影 2019 - Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954) 的相似度: 0.2344
#     与电影 2020 - Dangerous Liaisons (1988) 的相似度: 0.2800
#     与电影 485 - Last Action Hero (1993) 的相似度: 0.2804
#     与电影 2025 - Lolita (1997) 的相似度: 0.1547
#     与电影 1005 - D3: The Mighty Ducks (1996) 的相似度: 0.1683
#     与电影 493 - Menace II Society (1993) 的相似度: 0.1805
#     与电影 2542 - Lock, Stock & Two Smoking Barrels (1998) 的相似度: 0.3109
#     与电影 1013 - Parent Trap, The (1961) 的相似度: 0.2348
#     与电影 1527 - Fifth Element, The (1997) 的相似度: 0.3863
#     与电影 2568 - Mod Squad, The (1999) 的相似度: 0.1575
#     与电影 3081 - Sleepy Hollow (1999) 的相似度: 0.3204
#     与电影 3082 - World Is Not Enough, The (1999) 的相似度: 0.3165
#     与电影 2064 - Roger & Me (1989) 的相似度: 0.3307
#     与电影 2085 - 101 Dalmatians (1961) 的相似度: 0.3385
#     与电影 2089 - Rescuers Down Under, The (1990) 的相似度: 0.2560
#     与电影 3633 - On Her Majesty's Secret Service (1969) 的相似度: 0.1938
#     与电影 3638 - Moonraker (1979) 的相似度: 0.2639
#     与电影 2103 - Tall Tale (1994) 的相似度: 0.0901
#     与电影 1597 - Conspiracy Theory (1997) 的相似度: 0.3175
#     与电影 1090 - Platoon (1986) 的相似度: 0.3464
#     与电影 2628 - Star Wars: Episode I - The Phantom Menace (1999) 的相似度: 0.4338
#     与电影 1608 - Air Force One (1997) 的相似度: 0.3555
#     与电影 2633 - Mummy, The (1932) 的相似度: 0.1270
#     与电影 1610 - Hunt for Red October, The (1990) 的相似度: 0.4265
#     与电影 2638 - Mummy's Tomb, The (1942) 的相似度: 0.0525
#     与电影 593 - Silence of the Lambs, The (1991) 的相似度: 0.4652
#     与电影 2644 - Dracula (1931) 的相似度: 0.1714
#     与电影 2646 - House of Dracula (1945) 的相似度: 0.0696
#     与电影 2647 - House of Frankenstein (1944) 的相似度: 0.0721
#     与电影 2648 - Frankenstein (1931) 的相似度: 0.2176
#     与电影 2649 - Son of Frankenstein (1939) 的相似度: 0.0905
#     与电影 2139 - Secret of NIMH, The (1982) 的相似度: 0.3050
#     与电影 2653 - Son of Dracula (1943) 的相似度: 0.0774
#     与电影 3176 - Talented Mr. Ripley, The (1999) 的相似度: 0.3124
#     与电影 1644 - I Know What You Did Last Summer (1997) 的相似度: 0.2504
#     与电影 1645 - Devil's Advocate, The (1997) 的相似度: 0.2993
#     与电影 2160 - Rosemary's Baby (1968) 的相似度: 0.2342
#     与电影 1650 - Washington Square (1997) 的相似度: 0.0574
#     与电影 1655 - Phantoms (1998) 的相似度: 0.1072
#     与电影 2683 - Austin Powers: The Spy Who Shagged Me (1999) 的相似度: 0.3496
#     与电影 2694 - Big Daddy (1999) 的相似度: 0.2775
#     与电影 3208 - Loaded Weapon 1 (1993) 的相似度: 0.2180
#     与电影 2700 - South Park: Bigger, Longer and Uncut (1999) 的相似度: 0.4284
#     与电影 2707 - Arlington Road (1999) 的相似度: 0.2149
#     与电影 2195 - Dirty Work (1998) 的相似度: 0.1755
#     与电影 2710 - Blair Witch Project, The (1999) 的相似度: 0.3063
#     与电影 2713 - Lake Placid (1999) 的相似度: 0.2032
#     与电影 2719 - Haunting, The (1999) 的相似度: 0.1977
#     与电影 2720 - Inspector Gadget (1999) 的相似度: 0.2329
#     与电影 3744 - Shaft (2000) 的相似度: 0.2079
#     与电影 165 - Die Hard: With a Vengeance (1995) 的相似度: 0.3364
#     与电影 3752 - Me, Myself and Irene (2000) 的相似度: 0.2254
#     与电影 1717 - Scream 2 (1997) 的相似度: 0.2478
#     与电影 1206 - Clockwork Orange, A (1971) 的相似度: 0.3490
#     与电影 1722 - Tomorrow Never Dies (1997) 的相似度: 0.3365
#     与电影 1219 - Psycho (1960) 的相似度: 0.3522
#     与电影 198 - Strange Days (1995) 的相似度: 0.2511
#     与电影 2761 - Iron Giant, The (1999) 的相似度: 0.3444
#     与电影 3273 - Scream 3 (2000) 的相似度: 0.2222
#     与电影 1753 - Half Baked (1998) 的相似度: 0.2106
#     与电影 2789 - Damien: Omen II (1978) 的相似度: 0.1242
#     与电影 2790 - Final Conflict, The (a.k.a. Omen III: The Final Conflict) (1981) 的相似度: 0.0908
#     与电影 1258 - Shining, The (1980) 的相似度: 0.3647
#     与电影 1772 - Blues Brothers 2000 (1998) 的相似度: 0.1833
#     与电影 1261 - Evil Dead II (Dead By Dawn) (1987) 的相似度: 0.2575
#     与电影 1262 - Great Escape, The (1963) 的相似度: 0.2572
#     与电影 2296 - Night at the Roxbury, A (1998) 的相似度: 0.1873
#     与电影 1278 - Young Frankenstein (1974) 的相似度: 0.4019
#     与电影 3325 - Next Best Thing, The (2000) 的相似度: 0.1198
#     与电影 1792 - U.S. Marshalls (1998) 的相似度: 0.2460
#     与电影 785 - Kingpin (1996) 的相似度: 0.3070
#     与电影 2836 - Outside Providence (1999) 的相似度: 0.1770
#     与电影 1301 - Forbidden Planet (1956) 的相似度: 0.1762
#     与电影 3863 - Cell, The (2000) 的相似度: 0.2497
#     与电影 2841 - Stir of Echoes (1999) 的相似度: 0.2090
#     与电影 2338 - I Still Know What You Did Last Summer (1998) 的相似度: 0.1963
#     与电影 1321 - American Werewolf in London, An (1981) 的相似度: 0.2648
#     与电影 2860 - Blue Streak (1999) 的相似度: 0.1712
#     与电影 1327 - Amityville Horror, The (1979) 的相似度: 0.1702
#     与电影 2353 - Enemy of the State (1998) 的相似度: 0.3499
#     与电影 1334 - Blob, The (1958) 的相似度: 0.1763
#     与电影 1340 - Bride of Frankenstein (1935) 的相似度: 0.1651
#     与电影 2366 - King Kong (1933) 的相似度: 0.2929
#     与电影 2367 - King Kong (1976) 的相似度: 0.2026
#     与电影 1350 - Omen, The (1976) 的相似度: 0.2180
#     与电影 2376 - View to a Kill, A (1985) 的相似度: 0.2270
#     与电影 330 - Tales from the Hood (1995) 的相似度: 0.1445
#     与电影 842 - Tales from the Crypt Presents: Bordello of Blood (1996) 的相似度: 0.1253
#     与电影 2888 - Drive Me Crazy (1999) 的相似度: 0.1159
#     与电影 3409 - Final Destination (2000) 的相似度: 0.1890
#     与电影 2393 - Star Trek: Insurrection (1998) 的相似度: 0.3181
#     与电影 3930 - Creature From the Black Lagoon, The (1954) 的相似度: 0.1109
#     与电影 1370 - Die Hard 2 (1990) 的相似度: 0.3659
#     与电影 3421 - Animal House (1978) 的相似度: 0.4134
#     与电影 1373 - Star Trek V: The Final Frontier (1989) 的相似度: 0.2880
#     与电影 879 - Relic, The (1997) 的相似度: 0.1875
#     与电影 1909 - X-Files: Fight the Future, The (1998) 的相似度: 0.3328
#     与电影 1911 - Doctor Dolittle (1998) 的相似度: 0.2299
#     与电影 2428 - Faculty, The (1998) 的相似度: 0.2047
#     与电影 1407 - Scream (1996) 的相似度: 0.3395
#     与电影 2949 - Dr. No (1962) 的相似度: 0.2623
#     与电影 2454 - Fly, The (1958) 的相似度: 0.1952
#     与电影 2455 - Fly, The (1986) 的相似度: 0.3068
#     与电影 2976 - Bringing Out the Dead (1999) 的相似度: 0.2077
#     与电影 420 - Beverly Hills Cop III (1994) 的相似度: 0.2390
#     与电影 2990 - Licence to Kill (1989) 的相似度: 0.2470
#     与电影 2991 - Live and Let Die (1973) 的相似度: 0.2358
#     与电影 3510 - Frequency (2000) 的相似度: 0.2634
#     与电影 1974 - Friday the 13th (1980) 的相似度: 0.2282
#     与电影 1982 - Halloween (1978) 的相似度: 0.2618
#     与电影 2502 - Office Space (1999) 的相似度: 0.3569
#     与电影 1994 - Poltergeist (1982) 的相似度: 0.3128
#     与电影 2527 - Westworld (1973) 的相似度: 0.2341
#     与电影 3552 - Caddyshack (1980) 的相似度: 0.3591
#     与电影 3745 - Titan A.E. (2000) 的相似度: 0.2494
#     与电影 3000 - Princess Mononoke, The (Mononoke Hime) (1997) 的相似度: 0.2514
#     与电影 3774 - House Party 2 (1991) 的相似度: 0.1091
#     与电影 3268 - Stop! Or My Mom Will Shoot (1992) 的相似度: 0.1844
#     与电影 585 - Brady Bunch Movie, The (1995) 的相似度: 0.3128
#     与电影 3053 - Messenger: The Story of Joan of Arc, The (1999) 的相似度: 0.1715
#     与电影 2800 - Little Nemo: Adventures in Slumberland (1992) 的相似度: 0.0810
#     与电影 6 - Heat (1995) 的相似度: 0.3198
#     与电影 521 - Romeo Is Bleeding (1993) 的相似度: 0.1246
#     与电影 11 - American President, The (1995) 的相似度: 0.3802
#     与电影 3104 - Midnight Run (1988) 的相似度: 0.2977
#     与电影 3618 - Small Time Crooks (2000) 的相似度: 0.2018
#     与电影 39 - Clueless (1995) 的相似度: 0.4637
#     与电影 45 - To Die For (1995) 的相似度: 0.3027
#     与电影 3634 - Seven Days in May (1964) 的相似度: 0.0955
#     与电影 556 - War Room, The (1993) 的相似度: 0.1202
#     与电影 1077 - Sleeper (1973) 的相似度: 0.2807
#     与电影 3266 - Man Bites Dog (C'est arrivé près de chez vous) (1992) 的相似度: 0.1489
#     与电影 60 - Indian in the Cupboard, The (1995) 的相似度: 0.2574
#     与电影 2117 - Nineteen Eighty-Four (1984) 的相似度: 0.1561
#     与电影 70 - From Dusk Till Dawn (1996) 的相似度: 0.3094
#     与电影 2118 - Dead Zone, The (1983) 的相似度: 0.2310
#     与电影 2119 - Maximum Overdrive (1986) 的相似度: 0.1506
#     与电影 2641 - Superman II (1980) 的相似度: 0.3268
#     与电影 2643 - Superman IV: The Quest for Peace (1987) 的相似度: 0.2352
#     与电影 1625 - Game, The (1997) 的相似度: 0.3359
#     与电影 610 - Heavy Metal (1981) 的相似度: 0.2657
#     与电影 2148 - House (1986) 的相似度: 0.1813
#     与电影 2149 - House II: The Second Story (1987) 的相似度: 0.1189
#     与电影 3700 - Brother from Another Planet, The (1984) 的相似度: 0.1621
#     与电影 3708 - Firestarter (1984) 的相似度: 0.2026
#     与电影 125 - Flirting With Disaster (1996) 的相似度: 0.2483
#     与电影 2176 - Rope (1948) 的相似度: 0.1543
#     与电影 1674 - Witness (1985) 的相似度: 0.3368
#     与电影 659 - Purple Noon (1960) 的相似度: 0.0351
#     与电影 1171 - Bob Roberts (1992) 的相似度: 0.2386
#     与电影 661 - James and the Giant Peach (1996) 的相似度: 0.3260
#     与电影 1179 - Grifters, The (1990) 的相似度: 0.2811
#     与电影 2202 - Lifeboat (1944) 的相似度: 0.1455
#     与电影 3740 - Big Trouble in Little China (1986) 的相似度: 0.3071
#     与电影 3741 - Badlands (1973) 的相似度: 0.1326
#     与电影 674 - Barbarella (1968) 的相似度: 0.1984
#     与电影 1189 - Thin Blue Line, The (1988) 的相似度: 0.1868
#     与电影 1199 - Brazil (1985) 的相似度: 0.3124
#     与电影 3763 - F/X (1986) 的相似度: 0.2715
#     与电影 1204 - Lawrence of Arabia (1962) 的相似度: 0.2692
#     与电影 3253 - Wayne's World (1992) 的相似度: 0.4616
#     与电影 3770 - Dreamscape (1984) 的相似度: 0.1966
#     与电影 187 - Party Girl (1995) 的相似度: 0.1529
#     与电影 2241 - Class (1983) 的相似度: 0.1360
#     与电影 1218 - Killer, The (Die xue shuang xiong) (1989) 的相似度: 0.1802
#     与电影 1729 - Jackie Brown (1997) 的相似度: 0.3164
#     与电影 1222 - Full Metal Jacket (1987) 的相似度: 0.3531
#     与电影 1227 - Once Upon a Time in America (1984) 的相似度: 0.1412
#     与电影 3786 - But I'm a Cheerleader (1999) 的相似度: 0.1179
#     与电影 1747 - Wag the Dog (1997) 的相似度: 0.3959
#     与电影 1748 - Dark City (1998) 的相似度: 0.3138
#     与电影 1243 - Rosencrantz and Guildenstern Are Dead (1990) 的相似度: 0.2424
#     与电影 1248 - Touch of Evil (1958) 的相似度: 0.2048
#     与电影 1249 - Nikita (La Femme Nikita) (1990) 的相似度: 0.2666
#     与电影 3300 - Pitch Black (2000) 的相似度: 0.1999
#     与电影 235 - Ed Wood (1994) 的相似度: 0.3918
#     与电影 748 - Arrival, The (1996) 的相似度: 0.2309
#     与电影 750 - Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963) 的相似度: 0.3483
#     与电影 2288 - Thing, The (1982) 的相似度: 0.2503
#     与电影 2289 - Player, The (1992) 的相似度: 0.3638
#     与电影 2808 - Universal Soldier (1992) 的相似度: 0.2255
#     与电影 2311 - 2010 (1984) 的相似度: 0.2195
#     与电影 3338 - For All Mankind (1989) 的相似度: 0.0612
#     与电影 2322 - Soldier (1998) 的相似度: 0.1831
#     与电影 788 - Nutty Professor, The (1996) 的相似度: 0.3690
#     与电影 1306 - Until the End of the World (Bis ans Ende der Welt) (1991) 的相似度: 0.1226
#     与电影 1313 - Mad Dog Time (1996) 的相似度: 0.0543
#     与电影 293 - Professional, The (a.k.a. Leon: The Professional) (1994) 的相似度: 0.3124
#     与电影 1845 - Zero Effect (1998) 的相似度: 0.2568
#     与电影 2871 - Deliverance (1972) 的相似度: 0.2900
#     与电影 319 - Shallow Grave (1994) 的相似度: 0.1965
#     与电影 3920 - Faraway, So Close (In Weiter Ferne, So Nah!) (1993) 的相似度: 0.0865
#     与电影 2901 - Phantasm (1979) 的相似度: 0.1520
#     与电影 2390 - Little Voice (1998) 的相似度: 0.1773
#     与电影 3420 - ...And Justice for All (1979) 的相似度: 0.1392
#     与电影 1885 - Opposite of Sex, The (1998) 的相似度: 0.3126
#     与电影 348 - Bullets Over Broadway (1994) 的相似度: 0.2714
#     与电影 2912 - Limey, The (1999) 的相似度: 0.2192
#     与电影 866 - Bound (1996) 的相似度: 0.2525
#     与电影 2917 - Body Heat (1981) 的相似度: 0.2372
#     与电影 2409 - Rocky II (1979) 的相似度: 0.2588
#     与电影 3435 - Double Indemnity (1944) 的相似度: 0.2150
#     与电影 1388 - Jaws 2 (1978) 的相似度: 0.2167
#     与电影 2411 - Rocky IV (1985) 的相似度: 0.2312
#     与电影 3952 - Contender, The (2000) 的相似度: 0.1641
#     与电影 2419 - Extremities (1986) 的相似度: 0.1063
#     与电影 903 - Vertigo (1958) 的相似度: 0.2933
#     与电影 2952 - Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight) (1996) 的相似度: 0.1599
#     与电影 3474 - Retroactive (1997) 的相似度: 0.0365
#     与电影 2973 - Crimes and Misdemeanors (1989) 的相似度: 0.2179
#     与电影 1953 - French Connection, The (1971) 的相似度: 0.2909
#     与电影 1958 - Terms of Endearment (1983) 的相似度: 0.2746
#     与电影 2985 - Robocop (1987) 的相似度: 0.3757
#     与电影 1965 - Repo Man (1984) 的相似度: 0.2705
#     与电影 3503 - Solaris (Solyaris) (1972) 的相似度: 0.1074
#     与电影 431 - Carlito's Way (1993) 的相似度: 0.2216
#     与电影 3505 - No Way Out (1987) 的相似度: 0.2255
#     与电影 3507 - Odd Couple, The (1968) 的相似度: 0.2483
#     与电影 951 - His Girl Friday (1940) 的相似度: 0.2056
#     与电影 3521 - Mystery Train (1989) 的相似度: 0.1476
#     与电影 968 - Night of the Living Dead (1968) 的相似度: 0.2159
#     与电影 1997 - Exorcist, The (1973) 的相似度: 0.3138
#     与电影 2511 - Long Goodbye, The (1973) 的相似度: 0.1033
#     与电影 3032 - Omega Man, The (1971) 的相似度: 0.1438
#     与电影 3551 - Marathon Man (1976) 的相似度: 0.1973
#     与电影 2528 - Logan's Run (1976) 的相似度: 0.2675
#     与电影 3044 - Dead Again (1991) 的相似度: 0.2727
#     与电影 3556 - Virgin Suicides, The (1999) 的相似度: 0.1672
#     与电影 2530 - Beneath the Planet of the Apes (1970) 的相似度: 0.2098
#     与电影 2533 - Escape from the Planet of the Apes (1971) 的相似度: 0.2166
#     与电影 3052 - Dogma (1999) 的相似度: 0.3776
#     与电影 2553 - Village of the Damned (1960) 的相似度: 0.1288
#     与电影 2554 - Children of the Damned (1963) 的相似度: 0.0988
#     与电影 3070 - Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984) 的相似度: 0.2714
#     与电影 3 - Grumpier Old Men (1995) 的相似度: 0.2587
#     与电影 2053 - Honey, I Blew Up the Kid (1992) 的相似度: 0.2574
#     与电影 5 - Father of the Bride Part II (1995) 的相似度: 0.2505
#     与电影 2059 - Parent Trap, The (1998) 的相似度: 0.2256
#     与电影 38 - It Takes Two (1995) 的相似度: 0.0831
#     与电影 2106 - Swing Kids (1993) 的相似度: 0.1929
#     与电影 64 - Two if by Sea (1996) 的相似度: 0.1331
#     与电影 74 - Bed of Roses (1996) 的相似度: 0.1401
#     与电影 2134 - Weird Science (1985) 的相似度: 0.2949
#     与电影 94 - Beautiful Girls (1996) 的相似度: 0.1735
#     与电影 2144 - Sixteen Candles (1984) 的相似度: 0.3454
#     与电影 2146 - St. Elmo's Fire (1985) 的相似度: 0.2348
#     与电影 2154 - How Stella Got Her Groove Back (1998) 的相似度: 0.1275
#     与电影 118 - If Lucy Fell (1996) 的相似度: 0.1225
#     与电影 122 - Boomerang (1992) 的相似度: 0.1943
#     与电影 135 - Down Periscope (1996) 的相似度: 0.1668
#     与电影 160 - Congo (1995) 的相似度: 0.2538
#     与电影 185 - Net, The (1995) 的相似度: 0.2881
#     与电影 195 - Something to Talk About (1995) 的相似度: 0.1766
# ...
#     与电影 3778 - On Our Merry Way (1948) 的相似度: 0.0723
#     与电影 1764 - Tainted (1998) 的相似度: 0.0404
#     与电影 3828 - Better Living (1998) 的相似度: 0.0286
#     与电影 1787 - Paralyzing Fear: The Story of Polio in America, A (1998) 的相似度: 0.0286
#     与电影 3866 - Sunset Strip (2000) 的相似度: 0.0181
#     与电影 3880 - Ballad of Ramblin' Jack, The (2000) 的相似度: 0.0108
#     与电影 3883 - Catfish in Black Bean Sauce (2000) 的相似度: 0.0417
#     与电影 3887 - Went to Coney Island on a Mission From God... Be Back by Five (1998) 的相似度: 0.0202
#     与电影 3891 - Turn It Up (2000) 的相似度: 0.0181
#     与电影 1852 - Love Walked In (1998) 的相似度: 0.0404
#     与电影 3899 - Circus (2000) 的相似度: 0.0466
#     与电影 1893 - Beyond Silence (1996) 的相似度: 0.0649
#     与电影 1908 - Resurrection Man (1998) 的相似度: 0.0404
#     与电影 3894 - Solas (1999) 的相似度: 0.0381
#     与电影 394 - Coldblooded (1995) 的相似度: 0.0490
#     与电影 2237 - Without Limits (1998) 的相似度: 0.0582
#     与电影 867 - Carpool (1996) 的相似度: 0.0172
#     与电影 2031 - $1,000,000 Duck (1971) 的相似度: 0.1088
#     与电影 2637 - Mummy's Hand, The (1940) 的相似度: 0.0933
#     与电影 2449 - Garbage Pail Kids Movie, The (1987) 的相似度: 0.0554
#     与电影 888 - Land Before Time III: The Time of the Great Giving (1995) 的相似度: 0.0596
#     与电影 77 - Nico Icon (1995) 的相似度: 0.0428
#     与电影 2254 - Choices (1981) 的相似度: 0.0404
#     与电影 3402 - Turtle Diary (1985) 的相似度: 0.0421
#     与电影 38 - It Takes Two (1995) 的相似度: 0.0475
#     与电影 3031 - Repossessed (1990) 的相似度: 0.1028
#     与电影 1520 - Commandments (1997) 的相似度: 0.0224
#     与电影 3137 - Sea Wolves, The (1980) 的相似度: 0.1079
#     与电影 3585 - Great Locomotive Chase, The (1956) 的相似度: 0.0686
#     与电影 3781 - Shaft in Africa (1973) 的相似度: 0.0565
#     与电影 2215 - Rich and Strange (1932) 的相似度: 0.0487
#     与电影 1528 - Intimate Relations (1996) 的相似度: 0.0286
#     与电影 2464 - Trick or Treat (1986) 的相似度: 0.0143
#     与电影 2800 - Little Nemo: Adventures in Slumberland (1992) 的相似度: 0.0556
#     与电影 3442 - Band of the Hand (1986) 的相似度: 0.0714
#     与电影 1990 - Prom Night IV: Deliver Us From Evil (1992) 的相似度: 0.0432
#     与电影 291 - Poison Ivy II (1995) 的相似度: 0.0453
#     与电影 433 - Clean Slate (1994) 的相似度: 0.0505
#     与电影 2566 - Doug's 1st Movie (1999) 的相似度: 0.0693
#     与电影 1324 - Amityville: Dollhouse (1996) 的相似度: 0.0294
#     与电影 1439 - Meet Wally Sparks (1997) 的相似度: 0.0465
#     与电影 3611 - Saludos Amigos (1943) 的相似度: 0.0756
#     与电影 3665 - Curse of the Puppet Master (1998) 的相似度: 0.0452
#     与电影 1750 - Star Kid (1997) 的相似度: 0.0622
#     与电影 1426 - Zeus and Roxanne (1997) 的相似度: 0.0431
#     与电影 83 - Once Upon a Time... When We Were Colored (1995) 的相似度: 0.0317
#     与电影 3302 - Beautiful People (1999) 的相似度: 0.0365
#     与电影 1325 - Amityville: A New Generation (1993) 的相似度: 0.0476
#     与电影 1534 - Bonheur, Le (1965) 的相似度: 0.0361
#     与电影 632 - Land and Freedom (Tierra y libertad) (1995) 的相似度: 0.0487
#     与电影 3056 - Oxygen (1999) 的相似度: 0.0330
#     与电影 1055 - Shadow Conspiracy (1997) 的相似度: 0.0666
#     与电影 3522 - Sacco and Vanzetti (Sacco e Vanzetti) (1971) 的相似度: 0.0466
#     与电影 3670 - Story of G.I. Joe, The (1945) 的相似度: 0.0723
#     与电影 3563 - Crow: Salvation, The (2000) 的相似度: 0.0336
#     与电影 1809 - Hana-bi (1997) 的相似度: 0.0375
#     与电影 567 - Kika (1993) 的相似度: 0.0350
#     与电影 2226 - Ring, The (1927) 的相似度: 0.0404
#     与电影 2507 - Breakfast of Champions (1999) 的相似度: 0.0244
#     与电影 3626 - 8 1/2 Women (1999) 的相似度: 0.0365
#     与电影 1780 - Ayn Rand: A Sense of Life (1997) 的相似度: 0.0361
#     与电影 1815 - Eden (1997) 的相似度: 0.0404
#     与电影 3537 - Where the Money Is (2000) 的相似度: 0.0225
#     与电影 1444 - Guantanamera (1994) 的相似度: 0.0143
#     与电影 1770 - B. Monkey (1998) 的相似度: 0.0540
#     与电影 3474 - Retroactive (1997) 的相似度: 0.0417
#     与电影 2185 - I Confess (1953) 的相似度: 0.0648
#     与电影 2205 - Mr. & Mrs. Smith (1941) 的相似度: 0.0700
#     与电影 1427 - Turbulence (1997) 的相似度: 0.0810
#     与电影 1657 - Wonderland (1997) 的相似度: 0.0463
#     与电影 3184 - Montana (1998) 的相似度: 0.0542
#     与电影 3288 - Cotton Mary (1999) 的相似度: 0.0202
#     与电影 3775 - Make Mine Music (1946) 的相似度: 0.0505
#     与电影 1602 - Leave It to Beaver (1997) 的相似度: 0.0614
#     与电影 1720 - Time Tracers (1995) 的相似度: 0.0330
#     与电影 1826 - Barney's Great Adventure (1998) 的相似度: 0.1092
#     与电影 1890 - Little Boy Blue (1997) 的相似度: 0.0330
#     与电影 2101 - Squanto: A Warrior's Tale (1994) 的相似度: 0.0448
#     与电影 2256 - Parasite (1982) 的相似度: 0.0381
#     与电影 2783 - Tomb of Ligeia, The (1965) 的相似度: 0.0428
#     与电影 3205 - Black Sunday (La Maschera Del Demonio) (1960) 的相似度: 0.0606
#     与电影 3490 - Horror Express (1972) 的相似度: 0.0104
#     与电影 3796 - Wisdom of Crocodiles, The (a.k.a. Immortality) (2000) 的相似度: 0.0365
#     与电影 3850 - Whatever Happened to Aunt Alice? (1969) 的相似度: 0.0350
#     与电影 3938 - Slumber Party Massacre, The (1982) 的相似度: 0.0242
#     与电影 3941 - Sorority House Massacre (1986) 的相似度: 0.0294
#     与电影 2545 - Relax... It's Just Sex (1998) 的相似度: 0.0365
#     与电影 2766 - Adventures of Sebastian Cole, The (1998) 的相似度: 0.0074
#     与电影 2775 - Head On (1998) 的相似度: 0.0117
#     与电影 297 - Panther (1995) 的相似度: 0.0577
#     与电影 470 - House Party 3 (1994) 的相似度: 0.0590
#     与电影 885 - Bogus (1996) 的相似度: 0.0582
#     与电影 1878 - Woo (1998) 的相似度: 0.0244
#     与电影 3131 - Broadway Damage (1997) 的相似度: 0.0286
#     与电影 966 - Walk in the Sun, A (1945) 的相似度: 0.0361
#     与电影 3592 - Time Masters (Les Maîtres du Temps) (1982) 的相似度: 0.0428
#     与电影 2635 - Mummy's Curse, The (1944) 的相似度: 0.0687
#     与电影 1583 - Simple Wish, A (1997) 的相似度: 0.0088
#     与电影 462 - Good Man in Africa, A (1994) 的相似度: 0.0603
#     与电影 2191 - Merry War, A (1997) 的相似度: 0.0428
#     与电影 3283 - Minnie and Moskowitz (1971) 的相似度: 0.0432
#     与电影 3586 - Idolmaker, The (1980) 的相似度: 0.0565
#     与电影 244 - Gumby: The Movie (1995) 的相似度: 0.0269
#     与电影 2834 - Very Thought of You, The (1998) 的相似度: 0.0112
#     与电影 2886 - Adventures of Elmo in Grouchland, The (1999) 的相似度: 0.0466
#     与电影 341 - Double Happiness (1994) 的相似度: 0.0305
#     与电影 1896 - Cousin Bette (1998) 的相似度: 0.0655
#     与电影 706 - Sunset Park (1996) 的相似度: 0.0286
#     与电影 834 - Phat Beach (1996) 的相似度: 0.0202
#     与电影 732 - Original Gangstas (1996) 的相似度: 0.0361
#     与电影 3648 - Abominable Snowman, The (1957) 的相似度: 0.0286
#     与电影 2234 - Let's Talk About Sex (1998) 的相似度: 0.0495
#     与电影 219 - Cure, The (1995) 的相似度: 0.0556
#     与电影 526 - Savage Nights (Nuits fauves, Les) (1992) 的相似度: 0.0165
#     与电影 2892 - New Rose Hotel (1998) 的相似度: 0.0244
#     与电影 1714 - Never Met Picasso (1996) 的相似度: 0.0404
#     与电影 3400 - We're Back! A Dinosaur's Story (1993) 的相似度: 0.0389
#     与电影 1850 - I Love You, Don't Touch Me! (1998) 的相似度: 0.0350
#     与电影 3207 - Snows of Kilimanjaro, The (1952) 的相似度: 0.0404
#     与电影 2569 - Among Giants (1998) 的相似度: 0.0305
#     与电影 1609 - 187 (1997) 的相似度: 0.0244
#     与电影 3533 - Actor's Revenge, An (Yukinojo Henge) (1963) 的相似度: 0.0330
#     与电影 1596 - Career Girls (1997) 的相似度: 0.0525
#     与电影 1851 - Leather Jacket Love Story (1997) 的相似度: 0.0404
#     与电影 2503 - Apple, The (Sib) (1998) 的相似度: 0.0153
#     与电影 114 - Margaret's Museum (1995) 的相似度: 0.0269
#     与电影 3293 - Conceiving Ada (1997) 的相似度: 0.0181
#     与电影 384 - Bad Company (1995) 的相似度: 0.0633
#     与电影 304 - Roommates (1995) 的相似度: 0.0500
#     与电影 2777 - Cobra (1925) 的相似度: 0.0606
#     与电影 2778 - Never Talk to Strangers (1995) 的相似度: 0.0247
#     与电影 103 - Unforgettable (1996) 的相似度: 0.0382
#     与电影 874 - Killer: A Journal of Murder (1995) 的相似度: 0.0458
#     与电影 3443 - Born American (1986) 的相似度: 0.0202
#     与电影 1565 - Head Above Water (1996) 的相似度: 0.0336
#     与电影 1671 - Deceiver (1997) 的相似度: 0.0463
#     与电影 757 - Ashes of Time (1994) 的相似度: 0.0233
#     与电影 3187 - Trans (1998) 的相似度: 0.0466
#     与电影 3352 - Brown's Requiem (1998) 的相似度: 0.0233
#     与电影 1567 - Last Time I Committed Suicide, The (1997) 的相似度: 0.0143
#     与电影 703 - Boys (1996) 的相似度: 0.0458
#     与电影 189 - Reckless (1995) 的相似度: 0.0108
#     与电影 716 - Switchblade Sisters (1975) 的相似度: 0.0353
#     与电影 2955 - Penitentiary II (1982) 的相似度: 0.0404
#     与电影 981 - Dangerous Ground (1997) 的相似度: 0.0233
#     与电影 1000 - Curdled (1996) 的相似度: 0.0278
#     与电影 1138 - Dadetown (1995) 的相似度: 0.0458
#     与电影 1470 - Rhyme & Reason (1997) 的相似度: 0.0404
#     与电影 1551 - Buddy (1997) 的相似度: 0.0580
#     与电影 1662 - Gang Related (1997) 的相似度: 0.0196
#     与电影 1886 - I Got the Hook Up (1998) 的相似度: 0.0233
#     与电影 2358 - Savior (1998) 的相似度: 0.0404
#     与电影 2586 - Goodbye, Lover (1999) 的相似度: 0.0337
#     与电影 3373 - Buck and the Preacher (1972) 的相似度: 0.0466
#     与电影 1117 - Eighth Day, The (Le Huitième jour ) (1996) 的相似度: 0.0128
#     与电影 2904 - Rain (1932) 的相似度: 0.0336
#     与电影 3305 - Bluebeard (1944) 的相似度: 0.0286
#     与电影 3757 - Asylum (1972) 的相似度: 0.0404
#     与电影 263 - Ladybird Ladybird (1994) 的相似度: 0.0165
#     与电影 2673 - Eternity and a Day (Mia eoniotita ke mia mera ) (1998) 的相似度: 0.0305
#     与电影 2773 - Alice and Martin (Alice et Martin) (1998) 的相似度: 0.0112
#     与电影 791 - Last Klezmer: Leopold Kozlowski, His Life and Music, The (1995) 的相似度: 0.0404
#     与电影 1058 - Bitter Sugar (Azucar Amargo) (1996) 的相似度: 0.0244
#     与电影 3609 - Regret to Inform (1998) 的相似度: 0.0202
#     与电影 1743 - Arguing the World (1996) 的相似度: 0.0128
#     与电影 1724 - Full Speed (1996) 的相似度: 0.0404
#     与电影 1525 - Warriors of Virtue (1997) 的相似度: 0.0383
#     与电影 775 - Spirits of the Dead (Tre Passi nel Delirio) (1968) 的相似度: 0.0305
#     与电影 2636 - Mummy's Ghost, The (1944) 的相似度: 0.0122
#     与电影 3237 - Kestrel's Eye (Falkens öga) (1998) 的相似度: 0.0404
#     与电影 1329 - Blood For Dracula (Andy Warhol's Dracula) (1974) 的相似度: 0.0442
#     与电影 1349 - Nosferatu a Venezia (1986) 的相似度: 0.0432
#     与电影 3472 - Horror Hotel (a.k.a. The City of the Dead) (1960) 的相似度: 0.0404
#     与电影 3666 - Retro Puppetmaster (1999) 的相似度: 0.0361
#     与电影 3762 - Daughter of Dr. Jeckyll (1957) 的相似度: 0.0233
#     与电影 3875 - Devil Rides Out, The (1968) 的相似度: 0.0181
#     与电影 1891 - Ugly, The (1997) 的相似度: 0.0143
#     与电影 3303 - Black Tar Heroin: The Dark End of the Street (1999) 的相似度: 0.0181
#     与电影 75 - Big Bully (1996) 的相似度: 0.0286
#     与电影 3761 - Blood In, Blood Out (a.k.a. Bound by Honor) (1993) 的相似度: 0.0158
#     与电影 2833 - Lucie Aubrac (1997) 的相似度: 0.0202
#     与电影 3817 - Other Side of Sunday, The (Søndagsengler) (1996) 的相似度: 0.0336
#     与电影 3603 - Gay Deceivers, The (1969) 的相似度: 0.0233
#     与电影 2931 - Time of the Gypsies (Dom za vesanje) (1989) 的相似度: 0.0135
#     与电影 2602 - Mighty Peking Man (Hsing hsing wang) (1977) 的相似度: 0.0202
#     与电影 815 - Power 98 (1995) 的相似度: 0.0165
#     与电影 2213 - Waltzes from Vienna (1933) 的相似度: 0.0404
#     与电影 2217 - Elstree Calling (1930) 的相似度: 0.0404
#     与电影 975 - Something to Sing About (1937) 的相似度: 0.0286
#     与电影 1026 - So Dear to My Heart (1949) 的相似度: 0.0458
#     与电影 3202 - Even Dwarfs Started Small (Auch Zwerge haben klein angefangen) (1971) 的相似度: 0.0404
#     与电影 3232 - Seven Chances (1925) 的相似度: 0.0181
#     与电影 3376 - Fantastic Night, The (La Nuit Fantastique) (1949) 的相似度: 0.0404
#     与电影 3818 - Pot O' Gold (1941) 的相似度: 0.0165
#     与电影 2963 - Joe the King (1999) 的相似度: 0.0216
#     与电影 228 - Destiny Turns on the Radio (1995) 的相似度: 0.0383
#     与电影 1501 - Keys to Tulsa (1997) 的相似度: 0.0505
#     与电影 1575 - Gabbeh (1996) 的相似度: 0.0224
#     与电影 1685 - I Love You, I Love You Not (1996) 的相似度: 0.0361
#     与电影 2063 - Seventh Heaven (Le Septième ciel) (1997) 的相似度: 0.0286
#     与电影 106 - Nobody Loves Me (Keiner liebt mich) (1994) 的相似度: 0.0244
#     与电影 2557 - I Stand Alone (Seul contre tous) (1998) 的相似度: 0.0202
#     与电影 2705 - Late August, Early September (Fin août, début septembre) (1998) 的相似度: 0.0153
#     与电影 793 - My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993) 的相似度: 0.0269
#     与电影 3636 - Those Who Love Me Can Take the Train (Ceux qui m'aiment prendront le train) (1998) 的相似度: 0.0269
#     与电影 2740 - Kindred, The (1986) 的相似度: 0.0392
#     与电影 3523 - Taffin (1988) 的相似度: 0.0305
#     与电影 320 - Suture (1993) 的相似度: 0.0375
#     与电影 1636 - Stag (1997) 的相似度: 0.0181
#     与电影 3777 - Nekromantik (1987) 的相似度: 0.0135
#     与电影 3027 - Slaughterhouse 2 (1988) 的相似度: 0.0330
#     与电影 243 - Gordy (1995) 的相似度: 0.0383
#     与电影 3437 - Cool as Ice (1991) 的相似度: 0.0128
#     与电影 1494 - Sixth Man, The (1997) 的相似度: 0.0196
#     与电影 1718 - Stranger in the House (1997) 的相似度: 0.0165
#     与电影 3848 - Silent Fall (1994) 的相似度: 0.0286
#     与电影 1316 - Anna (1996) 的相似度: 0.0404
#     与电影 138 - Neon Bible, The (1995) 的相似度: 0.0286
#     与电影 530 - Second Best (1994) 的相似度: 0.0404
#     与电影 563 - Germinal (1993) 的相似度: 0.0108
#     与电影 584 - I Don't Want to Talk About It (De eso no se habla) (1993) 的相似度: 0.0404
#     与电影 607 - Century (1993) 的相似度: 0.0286
#     与电影 701 - Daens (1992) 的相似度: 0.0404
#     与电影 712 - Captives (1994) 的相似度: 0.0286
#     与电影 726 - Last Dance (1996) 的相似度: 0.0202
#     与电影 749 - Man from Down Under, The (1943) 的相似度: 0.0202
#     与电影 763 - Last of the High Kings, The (a.k.a. Summer Fling) (1996) 的相似度: 0.0404
#     与电影 827 - Convent, The (Convento, O) (1995) 的相似度: 0.0404
#     与电影 1070 - Macao (1952) 的相似度: 0.0571
#     与电影 1098 - Search for One-eye Jimmy, The (1996) 的相似度: 0.0202
#     与电影 1119 - Drunks (1997) 的相似度: 0.0233
#     与电影 1384 - Substance of Fire, The (1996) 的相似度: 0.0165
#     与电影 1531 - Losing Chase (1996) 的相似度: 0.0122
#     与电影 1548 - War at Home, The (1996) 的相似度: 0.0286
#     与电影 1563 - Dream With the Fishes (1997) 的相似度: 0.0069
#     与电影 1820 - Proposition, The (1998) 的相似度: 0.0404
#     与电影 1853 - Alan Smithee Film: Burn Hollywood Burn, An (1997) 的相似度: 0.0417
#     与电影 2214 - Number Seventeen (1932) 的相似度: 0.0404
#     与电影 2299 - Battle of the Sexes, The (1959) 的相似度: 0.0286
#     与电影 2317 - Alarmist, The (1997) 的相似度: 0.0143
#     与电影 2444 - 24 7: Twenty Four Seven (1997) 的相似度: 0.0404
#     与电影 2486 - 24-hour Woman (1998) 的相似度: 0.0135
#     与电影 2631 - Frogs for Snakes (1998) 的相似度: 0.0404
#     与电影 2811 - With Friends Like These... (1998) 的相似度: 0.0286
#     与电影 2830 - Cabaret Balkan (Bure Baruta) (1998) 的相似度: 0.0143
#     与电影 3126 - End of the Affair, The (1955) 的相似度: 0.0404
#     与电影 3149 - Diamonds (1999) 的相似度: 0.0286
#     与电影 3215 - Voyage of the Damned (1976) 的相似度: 0.0487
#     与电影 3229 - Another Man's Poison (1952) 的相似度: 0.0404
#     与电影 3337 - I'll Never Forget What's 'is Name (1967) 的相似度: 0.0286
#     与电影 3377 - Hangmen Also Die (1943) 的相似度: 0.0286
#     与电影 3413 - Impact (1949) 的相似度: 0.0286
#     与电影 3867 - All the Rage (a.k.a. It's the Rage) (1999) 的相似度: 0.0244
#     与电影 3876 - Jerry & Tom (1998) 的相似度: 0.0286
#     与电影 843 - Lotto Land (1995) 的相似度: 0.0404
#     与电影 2960 - Beefcake (1999) 的相似度: 0.0286
#     与电影 67 - Two Bits (1995) 的相似度: 0.0233
#     与电影 264 - Enfer, L' (1994) 的相似度: 0.0181
#     与电影 1364 - Zero Kelvin (Kjærlighetens kjøtere) (1995) 的相似度: 0.0286
#     与电影 1519 - Broken English (1996) 的相似度: 0.0202
#     与电影 1903 - Hav Plenty (1997) 的相似度: 0.0181
#     与电影 3460 - Hillbillys in a Haunted House (1967) 的相似度: 0.0404
#     与电影 3315 - Happy Go Lovely (1951) 的相似度: 0.0404
#     与电影 1532 - Sprung (1997) 的相似度: 0.0181
#     与电影 864 - Wife, The (1995) 的相似度: 0.0122
#     与电影 1664 - Nénette et Boni (1996) 的相似度: 0.0181
#     与电影 1782 - Little City (1998) 的相似度: 0.0181
#     与电影 1174 - Grosse Fatigue (1994) 的相似度: 0.0202
#     与电影 2218 - Juno and Paycock (1930) 的相似度: 0.0404
#     与电影 3570 - Last September, The (1999) 的相似度: 0.0135
#     与电影 2623 - Trippin' (1999) 的相似度: 0.0202
#     与电影 560 - Beans of Egypt, Maine, The (1994) 的相似度: 0.0153
#     与电影 820 - Death in the Garden (Mort en ce jardin, La) (1956) 的相似度: 0.0233
#     与电影 1313 - Mad Dog Time (1996) 的相似度: 0.0350
#     与电影 3905 - Specials, The (2000) 的相似度: 0.0153
#     与电影 404 - Brother Minister: The Assassination of Malcolm X (1994) 的相似度: 0.0404
#     与电影 3282 - Different for Girls (1996) 的相似度: 0.0128
#     与电影 3381 - Slaves to the Underground (1997) 的相似度: 0.0286
#     与电影 1509 - All Over Me (1997) 的相似度: 0.0090
#     与电影 1811 - Niagara, Niagara (1997) 的相似度: 0.0128
#     与电影 134 - Sonic Outlaws (1995) 的相似度: 0.0286
#     与电影 286 - Nemesis 2: Nebula (1995) 的相似度: 0.0404
#     与电影 3631 - It's in the Water (1998) 的相似度: 0.0233
#     与电影 2342 - Hard Core Logo (1996) 的相似度: 0.0269
#     与电影 3530 - Smoking/No Smoking (1993) 的相似度: 0.0404
#     与电影 283 - New Jersey Drive (1995) 的相似度: 0.0108
#     与电影 578 - Hour of the Pig, The (1993) 的相似度: 0.0404
#     与电影 2258 - Master Ninja I (1984) 的相似度: 0.0286
#     与电影 591 - Tough and Deadly (1995) 的相似度: 0.0286
#     与电影 1133 - Talking About Sex (1994) 的相似度: 0.0286
#     与电影 3123 - Spring Fever USA (a.k.a. Lauderdale) (1989) 的相似度: 0.0286
#     与电影 212 - Bushwhacked (1995) 的相似度: 0.0122

# %% [markdown]
# # 推荐ItemCF

# %%
# ---------------------------
# 推荐函数（ItemCF）
# ---------------------------
def ItemCF(user, user_item, item_similarity, N=10):
    """
    基于物品相似度为目标用户推荐物品
    参数:
      user: 当前目标用户
      user_item: dict, 格式为 {user: set(items)}，用户的行为数据
      item_similarity: dict, 格式为 {i: {j: similarity}}，物品相似度矩阵
      N: 推荐列表的长度
    返回:
      rec_list: 推荐的物品列表（按照得分降序排序）
    """
    # 获取当前用户已交互的物品集合
    interacted_items = user_item.get(user, set())
    scores = defaultdict(float)
    
    # 对于用户已经交互的每个物品
    for i in interacted_items:
        # 遍历与该物品相似的其他物品及相似度
        for j, sim in item_similarity.get(i, {}).items():
            if j in interacted_items:
                continue  # 已交互的物品不再推荐
            scores[j] += sim

    # 根据累加得分排序，取前 N 个物品
    ranked_items = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:N]
    rec_list = [item for item, score in ranked_items]
    return rec_list

# %% [markdown]
# # 评测函数

# %%
# ---------------------------
# 评测函数
# ---------------------------
def evaluate(user_item, test_data, item_similarity, N=10):
    """
    在测试集上评测推荐效果，计算 Precision、Recall、Coverage 和 Popularity
    """
    # 构建测试集的用户-物品字典
    test_user_item = defaultdict(set)
    for user, item in test_data:
        test_user_item[user].add(item)
    
    # 计算所有物品的流行度（出现次数），用于流行度评估
    item_popularity = defaultdict(int)
    for items in user_item.values():
        for item in items:
            item_popularity[item] += 1
    all_items = set(item_popularity.keys())
    
    hit = 0
    total_precision = 0
    total_recall = 0
    recommended_items_set = set()
    total_test_items = 0

    # 用于计算推荐列表的平均流行度
    total_popularity = 0
    total_rec = 0
    
    users = set(list(user_item.keys()) + list(test_user_item.keys()))
    
    for user in users:
        rec_items = ItemCF(user, user_item, item_similarity, N=N)
        true_items = test_user_item.get(user, set()) #从测试集中获取当前用户的真实交互物品集合
        hit += len(set(rec_items) & true_items) #计算当前用户推荐列表中有多少物品出现在真实交互集合中，即交集的大小
        
        total_precision += N #precision 分母
        total_recall += len(true_items) #recall 分母
        
        recommended_items_set.update(rec_items)
        
        total_test_items += len(true_items) #统计所有用户在测试集中真实交互物品的总数量，计算召回率
        
        #计算流行度
        for item in rec_items:
            total_popularity += math.log(1 + item_popularity.get(item, 0))  #取对数平滑数据防止极值
            total_rec += 1

    precision = hit / (total_precision + 1e-10)
    recall = hit / (total_recall + 1e-10)
    coverage = len(recommended_items_set) / len(all_items)
    popularity = total_popularity / (total_rec + 1e-10)
    
    return precision, recall, coverage, popularity

# %% [markdown]
# # 实验运行和结果输出

# %% [markdown]
# ### 普通

# %%
# ---------------------------
# 执行一次实验并输出评测结果
# ---------------------------

N = 10   # 推荐列表长度
precision, recall, coverage, popularity = evaluate(user_item, test_data, item_similarity,N=N)
print(f"\n评测结果：")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"Coverage:  {coverage:.4f}")
print(f"Popularity:{popularity:.4f}")
# Out:
# 评测结果：
# Precision: 0.2085
# Recall:    0.1005
# Coverage:  0.1267
# Popularity:7.3978

# %% [markdown]
# ### 归一化

# %%
# ---------------------------
# 执行一次实验并输出评测结果
# ---------------------------

N = 10   # 推荐列表长度
precision, recall, coverage, popularity = evaluate(user_item, test_data, item_similarity_norm,N=N)
print(f"\n评测结果：")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"Coverage:  {coverage:.4f}")
print(f"Popularity:{popularity:.4f}")
# Out:
# 评测结果：
# Precision: 0.2122
# Recall:    0.1023
# Coverage:  0.1440
# Popularity:7.3513
